# %% [markdown]
# # 问答机器人-从问题中提取相关实体和关系
#
# [同济子豪兄](https://space.bilibili.com/1900783) 2022-6-25

# %% [markdown]
# ## 导入工具包

# %%
import os
import ahocorasick
from tqdm import tqdm

# %% [markdown]
# ## 进入主目录

# %%
os.chdir('..')

# %%
cur_dir = os.getcwd()

# %% [markdown]
# ## 载入所有特征词

# %%
#　特征词txt文件路径
disease_path = os.path.join(cur_dir, 'dict/disease.txt')
department_path = os.path.join(cur_dir, 'dict/department.txt')
check_path = os.path.join(cur_dir, 'dict/check.txt')
drug_path = os.path.join(cur_dir, 'dict/drug.txt')
food_path = os.path.join(cur_dir, 'dict/food.txt')
producer_path = os.path.join(cur_dir, 'dict/producer.txt')
symptom_path = os.path.join(cur_dir, 'dict/symptom.txt')
deny_path = os.path.join(cur_dir, 'dict/deny.txt')

# %%
# 加载特征词
disease_wds = [i.strip() for i in open(disease_path,encoding="utf-8") if i.strip()]
department_wds = [i.strip() for i in open(department_path,encoding="utf-8") if i.strip()]
check_wds = [i.strip() for i in open(check_path,encoding="utf-8") if i.strip()]
drug_wds = [i.strip() for i in open(drug_path,encoding="utf-8") if i.strip()]
food_wds = [i.strip() for i in open(food_path,encoding="utf-8") if i.strip()]
producer_wds = [i.strip() for i in open(producer_path,encoding="utf-8") if i.strip()]
symptom_wds = [i.strip() for i in open(symptom_path,encoding="utf-8") if i.strip()]
region_words = set(disease_wds + department_wds + check_wds + drug_wds + food_wds + producer_wds + symptom_wds)
deny_words = [i.strip() for i in open(deny_path,encoding="utf-8") if i.strip()]

# %% [markdown]
# ## 所有实体对应的类型

# %%
wdtype_dict = dict()
for word in tqdm(region_words):
    wdtype_dict[word] = []
    if word in disease_wds:
        wdtype_dict[word].append('disease')
    if word in department_wds:
        wdtype_dict[word].append('department')
    if word in check_wds:
        wdtype_dict[word].append('check')
    if word in drug_wds:
        wdtype_dict[word].append('drug')
    if word in food_wds:
        wdtype_dict[word].append('food')
    if word in symptom_wds:
        wdtype_dict[word].append('symptom')
    if word in producer_wds:
        wdtype_dict[word].append('producer')
# Out:
#   0%|          | 0/43430 [00:00<?, ?it/s]
# 100%|██████████| 43430/43430 [00:24<00:00, 1768.90it/s]

# %%
wdtype_dict
# Out:
# {'现实解体': ['symptom'],
#  '家族性地中海热': ['disease'],
#  '鸿茅药酒': ['drug'],
#  '咽部神经鞘膜瘤': ['disease'],
#  '辅仁药业阿苯达唑胶囊': ['producer'],
#  '脚气病': ['disease'],
#  '良性纤维组织细胞瘤': ['disease'],
#  '番茄鱼肉末': ['food'],
#  '普伐他汀钠片': ['drug'],
#  '地塞米松抑制醛固酮试验': ['check'],
#  '湖北中佳肌苷注射液': ['producer'],
#  '黄芪鲤鱼汤': ['food'],
#  '陕西雪龙海姆普德红霉素软膏': ['producer'],
#  '克感额日敦片': ['drug'],
#  '前列腺肥大': ['symptom'],
#  '小儿过敏性紫癜肾炎': ['disease'],
#  '慢性胆管炎': ['disease'],
#  '广州白云山明兴苦参碱注射液': ['producer'],
#  '输卵管通气试验': ['check'],
#  '克拉霉素片': ['drug'],
#  '骨损伤': ['disease'],
#  '临汾宝珠地巴唑片': ['producer'],
#  '萝卜火腿粥': ['food'],
#  '武汉普生注射用盐酸克林霉素': ['producer'],
#  '冯了性回春散': ['producer'],
#  '新峰药业复方胆通片': ['producer'],
#  '硬肿症': ['disease', 'symptom'],
#  '鲁西药业盐酸黄酮哌酯片': ['producer'],
#  '麦味地黄口服液': ['drug'],
#  '秦巴药业克林霉素磷酸酯注射': ['producer'],
#  '延迟性应激反应': ['disease'],
#  '隐球菌病胶乳凝集试验': ['check'],
#  '小儿色素失调症': ['disease'],
#  '什菜面': ['food'],
#  '联合瓣膜病变': ['disease'],
#  '烤鱼': ['food'],
#  '田螺': ['food'],
#  '百合炖雪梨': ['food'],
#  '辰欣哈西奈德溶液': ['producer'],
#  '广西灵峰参芪首乌补汁': ['producer'],
#  '苯磺酸氨氯地平胶囊': ['drug'],
#  '济安堂蛇胆川贝液': ['producer'],
#  '神鹤药业产妇安胶囊': ['producer'],
#  '新乡华青曲咪新乳膏': ['producer'],
#  '瑞年前进制药盐酸左氧氟沙星': ['producer'],
#  '痔宁片': ['drug', 'producer'],
#  '太极集团盐酸西布曲明胶囊': ['producer'],
#  '山东泰谊复方灵芝颗粒': ['producer'],
#  '上海新亚注射用头孢噻肟钠': ['producer'],
#  '抗之霸阿莫西林克拉维酸钾干': ['producer'],
#  '角质化': ['symptom'],
#  '四川逢春小儿止咳糖浆': ['producer'],
#  '复视': ['symptom'],
#  '山西华元接骨续筋片': ['producer'],
#  '汉力达汉防己甲素片': ['producer'],
#  '年糕': ['food'],
#  '山香药业一清颗粒': ['producer'],
#  '先天性红细胞生成异常性贫血': ['disease'],
#  '头胀': ['symptom'],
#  '颅内黑色素瘤': ['disease'],
#  '三益醋酸氟轻松乳膏': ['producer'],
#  '北京京丰制药集团乙酰螺旋霉': ['producer'],
#  '德益宁': ['producer'],
#  '益康药业葡萄糖酸钙口服溶液': ['producer'],
#  '樱桃状血管瘤': ['disease'],
#  '小儿埃博拉病毒病': ['disease'],
#  '复方甘露醇注射液': ['drug'],
#  '盆腔下垂感': ['symptom'],
#  '四平吉特抗骨增生片': ['producer'],
#  '成都通德胰激肽原酶肠溶片': ['producer'],
#  '脑室受压移位': ['symptom'],
#  '炎黄本草药业明目地黄丸': ['producer'],
#  '勃然制药慈丹胶囊': ['producer'],
#  '肠气囊肿': ['disease'],
#  '焦虑症': ['disease'],
#  '广济药业碳酸氢钠注射液': ['producer'],
#  '淋巴管淤积': ['symptom'],
#  '血清补体旁路途径活性': ['check'],
#  '肝胆动态显像': ['check'],
#  '甘肃扶正甘油氯化钠注射液': ['producer'],
#  '卵巢宫内膜样肿瘤': ['disease'],
#  '促甲状腺激素': ['check'],
#  '惠松硅炭银片': ['producer'],
#  '产后虚脱': ['disease'],
#  '匹多莫德胶囊': ['drug'],
#  '益气聪明丸': ['drug'],
#  '流感嗜血杆菌感染': ['disease'],
#  '神经病性关节病': ['disease'],
#  '子宫颈平滑肌瘤': ['disease'],
#  '脑脓肿': ['disease', 'symptom'],
#  '膀胱输尿管返流显象': ['check'],
#  '内蒙古惠丰小儿麻甘颗粒': ['producer'],
#  '鲁抗乙酰螺旋霉素片': ['producer'],
#  'NOVARTISFARMA': ['producer'],
#  '湖南迪诺吡拉西坦片': ['producer'],
#  '瑞阳制药奋乃静注射液': ['producer'],
#  '炒胡萝卜土豆丝': ['food'],
#  '心排血量(CO)': ['check'],
#  '阴道分泌物检查': ['check'],
#  '山西普德银杏达莫注射液': ['producer'],
#  '持续性咳嗽': ['symptom'],
#  '头痛': ['disease', 'symptom'],
#  '贵州天方药业富马酸亚铁颗粒': ['producer'],
#  '视束病变': ['disease'],
#  '束臂试验': ['check'],
#  '西米苹果粥': ['food'],
#  '牙齿遇冷热痛': ['symptom'],
#  '天洋制药木香顺气丸': ['producer'],
#  '萝卜汁粥': ['food'],
#  '奇林药业谷维素片': ['producer'],
#  '肌肉酸痛': ['symptom'],
#  '海口市制药阿莫西林颗粒': ['producer'],
#  '山东绿因阿奇霉素片': ['producer'],
#  '钟山药业复方当归注射液': ['producer'],
#  '圣济堂杜仲颗粒': ['producer'],
#  '膀胱葡萄状肉瘤': ['disease'],
#  '姜枣鲫鱼粥': ['food'],
#  '耳湿疹': ['disease'],
#  '党参莲藕猪蹄汤': ['food'],
#  '太原药业阿替洛尔片': ['producer'],
#  '首乌豆腐汤': ['food'],
#  '宝珠制药甲氧氯普胺片': ['producer'],
#  '北京同仁堂十香暖脐膏': ['producer'],
#  '运动性疲劳': ['symptom'],
#  '荣心丸': ['drug'],
#  '尿锌（Zn）': ['check'],
#  '陕西欧珂食道平散': ['producer'],
#  '来立信': ['producer'],
#  '浙江医药（新昌）维生素A软': ['producer'],
#  '云南希陶妇炎舒片': ['producer'],
#  '赛而生物甲状腺片': ['producer'],
#  '沧州光明法可林滴眼液': ['producer'],
#  '广州嘉禾消炎利胆片': ['producer'],
#  '胡萝卜香菜粥': ['food'],
#  '产后劳伤': ['disease'],
#  '鼻中隔溃疡': ['disease'],
#  '巨人症及肢端肥大症': ['disease'],
#  '梅毒血清试验': ['check'],
#  '龙胆草蛋': ['food'],
#  '脑脊液内皮素': ['check'],
#  '杭州华威药业三七片': ['producer'],
#  '腹股沟直疝': ['disease'],
#  '西南药业葡萄糖注射液': ['producer'],
#  '肢体内翻': ['symptom'],
#  '本天药业依托红霉素片': ['producer'],
#  '振霖药业消癌平片': ['producer'],
#  '乳房活检': ['check'],
#  '常药氢氯噻嗪片': ['producer'],
#  '解痉镇痛酊': ['drug'],
#  'SW阴茎超声血流检测': ['check'],
#  '主动脉瓣上膈膜型狭窄': ['symptom'],
#  '凉拌莴苣丝': ['food'],
#  '梅毒性角膜病变': ['disease'],
#  '骨产道异常': ['symptom'],
#  '左金丸': ['drug'],
#  '费尔蒂综合征': ['disease'],
#  '老年人流行性感冒': ['disease'],
#  '山东仁和堂双嘧达莫片': ['producer'],
#  '脉络宁口服液': ['drug'],
#  '鼻脓涕有臭味': ['symptom'],
#  '昆药集团复方磷酸萘酚喹片': ['producer'],
#  '参茸卫生丸': ['drug'],
#  '西安大恒西洛他唑片': ['producer'],
#  '电解质紊乱': ['disease'],
#  '辰欣吲哚美辛软膏': ['producer'],
#  '食物过敏性哮喘': ['disease'],
#  '谷悦骨肽片': ['producer'],
#  'Howship...': ['symptom'],
#  '协力甘宝水飞蓟宾葡甲胺': ['producer'],
#  '积乳囊肿': ['disease'],
#  '九惠制药复方丹参片': ['producer'],
#  '康肾颗粒': ['drug'],
#  '室上性心律失常': ['symptom'],
#  '抗促甲状腺素受体抗体（TRAb）': ['check'],
#  '阿昔洛韦滴眼液': ['drug'],
#  '大便黑色粘稠': ['symptom'],
#  '情感障碍': ['disease'],
#  '天圣药业板蓝根注射液': ['producer'],
#  '颅内高压': ['symptom'],
#  '上消化道功能测定和显像': ['check'],
#  '抗线粒体抗体（AMA）': ['check'],
#  '阴茎动脉血压': ['check'],
#  '格林生物维生素D2片': ['producer'],
#  '胰岛素原': ['check'],
#  '胆囊良性肿瘤': ['disease'],
#  '燕窝鸽蛋汤': ['food'],
#  '胆汁溶菌试验': ['check'],
#  '桂林南药布美他尼片': ['producer'],
#  '友好维生素E软胶囊': ['producer'],
#  '电击样痛或刺痛的头痛': ['symptom'],
#  '脑干反射检查': ['check'],
#  '大同制药藿香正气胶囊': ['producer'],
#  '太极集团防风通圣丸': ['producer'],
#  '万年青制药消炎利胆片': ['producer'],
#  '老年人尿毒症性肺炎': ['disease'],
#  '北京益民药业氯氮平片': ['producer'],
#  '遗传性感觉神经病': ['disease'],
#  '浙江维康固元胶囊': ['producer'],
#  '华西制药耳聋通窍丸': ['producer'],
#  '北京同仁堂天王补心丸': ['producer'],
#  '怀庆堂注射用盐酸罂粟碱': ['producer'],
#  '广州白云山光华溴丙胺太林片': ['producer'],
#  '眼睑部有明显的...': ['symptom'],
#  '武汉福星复方奎宁注射液': ['producer'],
#  '双蚁药业双蚁祛湿通络胶囊': ['producer'],
#  '无极膏': ['drug'],
#  '胎势': ['check'],
#  '北京同仁堂抗饥消渴片': ['producer'],
#  '江苏四环甲钴胺注射液': ['producer'],
#  '万晟药业硝苯地平片': ['producer'],
#  '蘑菇（干）': ['food'],
#  '阴挺': ['disease'],
#  '化学性眼外伤': ['disease'],
#  '胃窦血管扩张症': ['disease'],
#  '依生生物制药冻干人用狂犬病': ['producer'],
#  '多系统器官功能衰竭': ['disease'],
#  '上海朝晖复方酮康唑软膏': ['producer'],
#  '创伤性肩关节后脱位': ['disease'],
#  '糖水樱桃': ['food'],
#  '平滑肌肉瘤': ['disease'],
#  '繁江儿肤康搽剂': ['producer'],
#  '面痛': ['symptom'],
#  '输血后肝炎': ['disease'],
#  '润阳药业盐酸氨溴索葡萄糖注': ['producer'],
#  '踝肱指数': ['check'],
#  '健朗药业奥拉西坦胶囊': ['producer'],
#  '青椒虾皮': ['food'],
#  '胎盘前置': ['symptom'],
#  '咳出黄色痰液': ['symptom'],
#  '妊娠合并甲状腺功能亢进': ['disease'],
#  '恒洛': ['producer'],
#  '诺金四君子颗粒': ['producer'],
#  '皮肤纤毛囊肿': ['disease'],
#  '发热伴眼睛充血': ['symptom'],
#  '肺弥散功能障碍': ['symptom'],
#  '江西天施康滋心阴胶囊': ['producer'],
#  '东药辛伐他汀片': ['producer'],
#  '武生旺宁': ['producer'],
#  '猪脊骨煲莲藕汤': ['food'],
#  '吉林金恒复方碳酸氢钠片': ['producer'],
#  '注射用头孢呋辛钠': ['drug', 'producer'],
#  '武汉海特注射用更昔洛韦': ['producer'],
#  '肉末烧海参': ['food'],
#  '疤痕形成': ['symptom'],
#  '膝关节内侧肿胀...': ['symptom'],
#  '莱恩药业莪术油注射液': ['producer'],
#  '老年人消化性溃疡': ['disease'],
#  '梅子肉': ['food'],
#  '复发性多发性软骨炎伴发的葡萄膜炎': ['disease'],
#  '成都一药醋酸可的松片': ['producer'],
#  '艾坦': ['producer'],
#  '骨旁骨肉瘤': ['disease'],
#  '蜀阳药业骨苓通痹丸': ['producer'],
#  '山东方明曲咪新乳膏': ['producer'],
#  '硬化性脂肪肉芽肿': ['disease'],
#  '太安堂药业克痒敏醑': ['producer'],
#  '沈阳一药维生素B2注射液': ['producer'],
#  '富马酸亚铁胶囊': ['drug'],
#  '普华克胜盐酸羟苄唑滴眼液': ['producer'],
#  '胰瘘': ['disease'],
#  '平菇莲子鸭羹': ['food'],
#  'ABO血型鉴定': ['check'],
#  '香砂胃痛散': ['drug'],
#  '冬菇苋菜汤': ['food'],
#  '吉欣益心巴迪然吉布亚颗粒': ['producer'],
#  '克林霉素磷酸酯注射液': ['drug'],
#  '解毒凉血合剂': ['drug'],
#  '眼眶纤维肉瘤': ['disease'],
#  '冬虫草鸡汤': ['food'],
#  '小儿健脾散': ['drug'],
#  '北京同仁堂润肌皮肤膏': ['producer'],
#  '吉林吉春抑亢丸': ['producer'],
#  '古方药业积雪苷胶囊': ['producer'],
#  '华澳药业十滴水': ['producer'],
#  '网络综合症': ['symptom'],
#  '重庆希尔安利胆片': ['producer'],
#  '肩节后脱位': ['symptom'],
#  '尿液去甲肾上腺素': ['check'],
#  '火腿白菜炖汤': ['food'],
#  '椰子饺': ['food'],
#  '香菇菜包': ['food'],
#  '丝瓜蘑菇肉片汤': ['food'],
#  '中化联合制药注射用异环磷酰': ['producer'],
#  '前列舒乐片': ['drug'],
#  '曲霉球': ['disease'],
#  '姜糖饮': ['food'],
#  '静脉出血': ['symptom'],
#  '甲磺酸伊马替尼胶囊': ['drug'],
#  '油菜苹果牛奶汁': ['food'],
#  '东药氟康唑胶囊': ['producer'],
#  '耻骨上痛': ['symptom'],
#  '单纯性肺嗜酸性粒细胞增多症': ['disease'],
#  '北京四环科宝注射用胸腺肽': ['producer'],
#  '塞替派注射液': ['drug'],
#  '黑龙江天宏益视颗粒': ['producer'],
#  '江西捷众复方水杨酸樟碘溶液': ['producer'],
#  '香蕉卷': ['food'],
#  '复方酮康唑发用洗剂': ['drug'],
#  '九泰药业醋酸氯己定痔疮栓': ['producer'],
#  '枸杞茯苓茶': ['food'],
#  '妇炎康丸': ['drug'],
#  '三原妇炎舒片': ['producer'],
#  '润怡玻璃酸钠滴眼液': ['producer'],
#  '膀胱囊肿': ['disease'],
#  '甲下出血': ['symptom'],
#  '天津金耀卡莫司汀注射液': ['producer'],
#  '赛立克药业氨苯蝶啶片': ['producer'],
#  '华夏药业莪术油注射液': ['producer'],
#  '外阴早期浸润性鳞癌': ['disease'],
#  '肥大性骨关节病': ['disease'],
#  '荠菜水饺': ['food'],
#  '德国夏菩莉芙敏片': ['producer'],
#  '河北万岁药业肾石通颗粒': ['producer'],
#  '血偏酸': ['symptom'],
#  '江西天施康中药白花蛇舌草注': ['producer'],
#  '阿托伐他汀钙分散片': ['drug'],
#  '鼻端肥大': ['symptom'],
#  '毛胚细胞瘤': ['disease'],
#  '武汉东信黄藤素片': ['producer'],
#  '马蹄鸡肉饺': ['food'],
#  '保龙康复方酮康唑软膏': ['producer'],
#  '湿啰音': ['symptom'],
#  '月经周期改变': ['symptom'],
#  '美图制药氯霉素滴眼液': ['producer'],
#  'SPECT显像': ['check'],
#  '河丰药业肿节风片': ['producer'],
#  '头颅向上生长呈塔形': ['symptom'],
#  '反复感冒': ['symptom'],
#  '新生儿肝炎综合征': ['disease'],
#  '催产素激惹试验': ['check'],
#  '吉林福康药业蒲地蓝消炎片': ['producer'],
#  '多发性内分泌肿瘤综合征Ⅰ型': ['disease'],
#  '他达拉非片': ['drug'],
#  '排尿疼痛': ['symptom'],
#  '仙河药业复方青黛丸': ['producer'],
#  '曲面体层摄影': ['check'],
#  '百合雪梨莲藕汤': ['food'],
#  '胡萝卜土豆丝': ['food'],
#  '人工关节置换术后关节感染': ['disease'],
#  '补体结合试验': ['check'],
#  '难入睡或易惊醒': ['symptom'],
#  '乌骨鸡': ['food'],
#  '菜花炒素虾仁': ['food'],
#  '静止性淋巴细胞性甲状腺炎': ['disease'],
#  '仙河药业蒲地蓝消炎片': ['producer'],
#  '狗肉': ['food'],
#  '泽泻茯苓鸡': ['food'],
#  '亚东生物小金丸': ['producer'],
#  '梅毒肾病': ['disease'],
#  '紫鑫药业消炎利胆片': ['producer'],
#  '广西济民制药消炎利胆片': ['producer'],
#  '山西汾河甲氧氯普胺片': ['producer'],
#  '重庆西南制药二厂磷酸氯喹片': ['producer'],
#  '泌尿道肿瘤': ['disease'],
#  '多索茶碱葡萄糖注射液': ['drug'],
#  '开同': ['producer'],
#  '山西云中曲克芦丁氯化钠注射': ['producer'],
#  '疱疹样皮炎': ['disease'],
#  '幼年型疱疹样皮炎': ['disease'],
#  '再造生血片': ['drug'],
#  '系统性红斑狼疮性关节炎': ['disease'],
#  '茉莉花粥': ['food'],
#  '永生堂度米芬含片': ['producer'],
#  '气管先天性疾病': ['disease'],
#  '僵鉧': ['disease'],
#  '角膜表面三角形胬肉': ['symptom'],
#  '晕可平糖浆': ['drug'],
#  '贵州同济堂四环素片': ['producer'],
#  '消化管蠕动不协调': ['symptom'],
#  '天洌舒康前列舒乐片': ['producer'],
#  '趾短小': ['symptom'],
#  '素樱桃肉': ['food'],
#  '伊维菌素片': ['drug'],
#  '怡力昕': ['producer'],
#  '甲癣': ['disease'],
#  '凝血功能障碍': ['symptom'],
#  '核桃鸡肉粥': ['food'],
#  '新红康': ['producer'],
#  '海南日中天头孢地尼分散片': ['producer'],
#  '餐后综合征': ['symptom'],
#  '宏利活络油': ['producer'],
#  '免疫缺陷性肺炎': ['disease'],
#  '继发性纵隔感染': ['disease'],
#  '湖南安邦景天三七片': ['producer'],
#  '莲藕萝卜': ['food'],
#  '湖北济安堂吗替麦考酚酯分散': ['producer'],
#  '九味健肾胶囊': ['drug'],
#  '颈椎增生': ['symptom'],
#  '小指外展试验': ['check'],
#  '卡前列甲酯栓': ['drug'],
#  '疫黄': ['disease'],
#  '三凹征': ['symptom'],
#  '气阴两虚': ['disease', 'symptom'],
#  '无睾丸': ['symptom'],
#  '阴茎结核疹': ['disease'],
#  '花菜饺': ['food'],
#  '胡萝卜香蕉汁': ['food'],
#  '着色杆菌病': ['disease'],
#  '沈阳康芝制药头孢氨苄甲氧苄': ['producer'],
#  '湖北远大天天明苄达赖氨酸滴': ['producer'],
#  '大同五洲通普卢利沙星胶囊': ['producer'],
#  '九芝堂天王补心丸': ['producer'],
#  '新和成药业酞丁安乳膏': ['producer'],
#  '鲁抗赛特复方甘草酸单铵S氯': ['producer'],
#  '尿红细胞位相': ['check'],
#  '强骨生血口服液': ['drug'],
#  '鸭血豆腐汤': ['food'],
#  '舒安灵': ['producer'],
#  '山西远景康业依托红霉素颗粒': ['producer'],
#  '六棉牌保儿安颗粒': ['producer'],
#  '黄豆莲藕排骨汤': ['food'],
#  '妇科的保健体检': ['check'],
#  '海蜇头': ['food'],
#  '疲劳': ['symptom'],
#  '鞘膜积水': ['symptom'],
#  '美辛唑酮红古豆醇酯栓': ['drug'],
#  '外阴白斑': ['symptom'],
#  '广州康和炔诺酮片': ['producer'],
#  '单心房': ['disease'],
#  '慢性肾炎': ['disease'],
#  '河北金芳醋酸氢化可的松滴眼': ['producer'],
#  '升主动脉瘤': ['disease'],
#  '来鑫': ['symptom'],
#  '湖南华纳肾炎四味胶囊': ['producer'],
#  '粘膜萎缩': ['symptom'],
#  '辰欣药业克霉唑乳膏': ['producer'],
#  '胎方位': ['check'],
#  '正大天晴复方甘草酸单铵注射': ['producer'],
#  '弥柠': ['producer'],
#  '绝经期乳腺癌': ['disease'],
#  '遗传性肥胖': ['disease', 'symptom'],
#  '猪肝笋尖粥': ['food'],
#  '慢脾风': ['disease'],
#  '双氯芬酸钠滴眼液': ['drug'],
#  '广东华润顺峰注射用盐酸罗哌': ['producer'],
#  '红细胞磷丙糖异构酶': ['check'],
#  '德昌祥复方阿胶补血膏': ['producer'],
#  '紧张性头痛': ['disease', 'symptom'],
#  '信谊万象氨甲环酸片': ['producer'],
#  '右上腹持续性剧...': ['symptom'],
#  '小肠脂肪瘤': ['disease'],
#  '心诚药业藿香正气片': ['producer'],
#  '胎盘成熟度': ['check'],
#  '星鲨制药维生素AE胶丸': ['producer'],
#  '浙江普洛康氧氟沙星片': ['producer'],
#  '澳美华制药消癌平片': ['producer'],
#  '番茄羊肉汤': ['food'],
#  '阴道异味': ['symptom'],
#  '京必妥新': ['producer'],
#  '大叶性肺炎': ['disease'],
#  '肌氨肽苷注射液': ['drug'],
#  '北京利龄恒泰盐酸二甲双胍肠': ['producer'],
#  '小儿胃肠道异物及异物性肠梗阻': ['disease'],
#  '尿流缓慢': ['symptom'],
#  '肛门直肠周围脓肿': ['disease'],
#  '急性阑尾炎': ['disease'],
#  '索坦': ['producer'],
#  '仁和堂硫酸沙丁胺醇片': ['producer'],
#  '病理反射检查': ['check'],
#  '六味地黄胶囊': ['drug'],
#  '耳源性眩晕': ['symptom'],
#  '真菌组织病理学': ['check'],
#  '血液粘度增高': ['symptom'],
#  '老年人糖尿病周围神经病': ['disease'],
#  '器质性精神障碍': ['symptom'],
#  '康诺药业盐酸左旋咪唑片': ['producer'],
#  '冰矾清毒生肌散': ['drug'],
#  '绿豆薏仁海带汤': ['food'],
#  '腹部“柔韧感”体征': ['symptom'],
#  '广州白云山和记黄埔中药鼻炎': ['producer'],
#  '真菌中毒症': ['disease'],
#  '风疹': ['disease'],
#  '进行性骨干发育不全': ['disease'],
#  '音叉检查': ['check'],
#  '泥鳅鱼茸粥': ['food'],
#  '甘露八味秦皮丸': ['producer'],
#  '盐酸二甲双胍缓释片': ['drug'],
#  '舌齿龈疼痛性粟...': ['symptom'],
#  '诺捷康前列舒乐胶囊': ['producer'],
#  '云鹏吡罗昔康片': ['producer'],
#  '甜杏仁羹': ['food'],
#  '气腹征': ['symptom'],
#  '花生粥': ['food'],
#  '河北康泰小儿复方磺胺甲噁唑': ['producer'],
#  '羊水过多': ['disease'],
#  '小儿军团病肾病': ['disease'],
#  '沮丧': ['symptom'],
#  '珍视明妥布霉素地塞米松滴眼': ['producer'],
#  '阿魏酸钠片': ['drug'],
#  '丽珠制药枸橼酸钾缓释片': ['producer'],
#  '神威药业清开灵注射液': ['producer'],
#  '银鱼芥菜': ['food'],
#  '曲莱': ['producer'],
#  '誉隆亚东药业抑亢丸': ['producer'],
#  '纤维鼻咽镜': ['check'],
#  '万邦德制药颠茄片': ['producer'],
#  '天津生物眼氨肽注射液': ['producer'],
#  '修正药业保胎无忧片': ['producer'],
#  '白菜仔滚鱼片汤': ['food'],
#  '南京正大天晴注射用盐酸吉西': ['producer'],
#  '酥香鲫鱼': ['food'],
#  '肾上腺素试验': ['check'],
#  '鼻石': ['disease'],
#  '肺泡蛋白沉着症': ['disease'],
#  '云南万裕盐酸非索非那定片': ['producer'],
#  '江西东风药业注射用头孢噻肟': ['producer'],
#  '武汉五景复方氯化钠滴眼液': ['producer'],
#  '湖北济安堂痔速宁片': ['producer'],
#  '遂成药业过氧化氢溶液': ['producer'],
#  '陕西天洋龙胆泻肝丸': ['producer'],
#  '浙江医药葡萄糖氯化钠注射液': ['producer'],
#  '全血砷': ['check'],
#  '丹东医创药业氨甲环酸注射液': ['producer'],
#  '山东信谊阿替洛尔片': ['producer'],
#  '阿司待因片': ['drug'],
#  '德国赫尔布兰德丙硫氧嘧啶片': ['producer'],
#  '河南鼎复康利巴韦林含片': ['producer'],
#  '冬笋土鸡煲': ['food'],
#  '肝脾肿大': ['symptom'],
#  '晶状体膨胀所致青光眼': ['disease'],
#  '人参黄芪莲子粥': ['food'],
#  'XYW': ['symptom'],
#  '河豚毒素中毒': ['disease'],
#  '鸟嘴样尖鼻': ['symptom'],
#  '天津太平洋甲硝唑片': ['producer'],
#  '南昌济生双橘颗粒': ['producer'],
#  '恒健维生素B1片': ['producer'],
#  '广州诺金小儿咳喘灵颗粒': ['producer'],
#  '牙疼': ['symptom'],
#  '珠江制药维生素A软胶囊': ['producer'],
#  '信谊天平硝苯地平片': ['producer'],
#  '栗子烧鸡块': ['food'],
#  '康惠制药宫颈癌片': ['producer'],
#  '痣细胞': ['symptom'],
#  '重庆迪康长江人工牛黄甲硝唑': ['producer'],
#  '静注人免疫球蛋白(pH4)': ['drug'],
#  '河南康华药业龙胆泻肝丸': ['producer'],
#  '反复出血': ['symptom'],
#  '以岭药业芪苈强心胶囊': ['producer'],
#  '广西芳菲止咳枇杷糖浆': ['producer'],
#  '石家庄御生堂五子衍宗丸': ['producer'],
#  '新四方千柏鼻炎片': ['producer'],
#  '天津天药药业醋酸泼尼松片': ['producer'],
#  '阴道毛滴虫检查': ['check'],
#  '素炒圆白菜': ['food'],
#  '浙江诚意药业氟尿嘧啶注射液': ['producer'],
#  '红癣': ['disease'],
#  '黄芪鲫鱼火锅': ['food'],
#  '尿黑酸尿与褐黄病': ['disease'],
#  '缺氧缺血性神经损伤': ['symptom'],
#  '女性腰骶生理性...': ['symptom'],
#  '生发丸': ['drug'],
#  '陕西君碧莎消癌平片': ['producer'],
#  '注射用硫酸长春新碱': ['drug', 'producer'],
#  '腹腔妊娠': ['disease'],
#  '小儿有机磷农药中毒': ['disease'],
#  '胃蛋白酶颗粒': ['drug'],
#  '中年男性体检': ['check'],
#  '酱芹菜': ['food'],
#  '蘑烧冬瓜': ['food'],
#  '沈阳绿洲鸦胆子油口服乳液': ['producer'],
#  '番茄青豆汤': ['food'],
#  '湖北明和红霉素肠溶微丸胶囊': ['producer'],
#  '半饱和氧分压（P50）': ['check'],
#  '石家庄御生堂防风通圣丸': ['producer'],
#  '山西临汾吡罗昔康片': ['producer'],
#  '用力肺活量（FVC)': ['check'],
#  '小儿止泻安颗粒': ['drug'],
#  '易亨制药双氯芬酸钠缓释胶囊': ['producer'],
#  '中央药业阿替洛尔片': ['producer'],
#  '血清镁(Mg2+,Mg)': ['check'],
#  '锅塌番茄': ['food'],
#  '胫骨结节骨软骨病': ['disease'],
#  '羊水泡沫试验': ['check'],
#  '苏州新宝注射用胰蛋白酶': ['producer'],
#  '霰粒肿': ['disease', 'symptom'],
#  '单唾液酸四己糖神经节苷脂钠盐注射液': ['drug'],
#  '白云山医乙酰螺旋霉素片': ['producer'],
#  '足跟痛': ['symptom'],
#  '先天性心脏病': ['disease'],
#  '蔡氏五宝体外培育牛黄': ['producer'],
#  '汞皮炎': ['disease'],
#  '左洛复': ['producer'],
#  '抗原皮内试验': ['check'],
#  '韩都氟康唑片': ['producer'],
#  '鳕鱼': ['food'],
#  '小麦生地百合羹': ['food'],
#  '牙外伤': ['disease'],
#  '赛兰': ['producer'],
#  '山药炖羊肉': ['food'],
#  '汉典制药补中益气颗粒': ['producer'],
#  '慢性乳突炎': ['disease'],
#  '颈部搏动': ['symptom'],
#  '大冢制药孟鲁司特钠咀嚼片': ['producer'],
#  '通用康力注射用核黄素磷酸钠': ['producer'],
#  '色觉': ['check'],
#  '方盛赖氨酸维B12颗粒': ['producer'],
#  '嗳腐': ['symptom'],
#  '康和别嘌醇片': ['producer'],
#  '山西天生补中益气丸': ['producer'],
#  '鼻中隔': ['check'],
#  '弱脉': ['symptom'],
#  '肛门外伤': ['disease'],
#  '乳块消胶囊': ['drug'],
#  '青阳盐酸左旋咪唑片': ['producer'],
#  '奶油南瓜羹': ['food'],
#  '非器质性性欲减退': ['disease'],
#  '升和药业石淋通颗粒': ['producer'],
#  '胆囊体积缩小': ['symptom'],
#  '手部血管损伤': ['disease'],
#  '前骨间神经卡压综合征': ['disease'],
#  '甲芪肝纤颗粒': ['drug'],
#  '华鲁高三尖杉酯碱氯化钠注射': ['producer'],
#  '临产后阵痛剧烈': ['symptom'],
#  '胃癌': ['disease'],
#  '霍奇金淋巴瘤': ['disease'],
#  '慢性腰部劳损': ['disease'],
#  '胡萝卜菠菜汁': ['food'],
#  '湖南中和氟尿嘧啶口服乳': ['producer'],
#  '橘皮粥': ['food'],
#  '粪便性状': ['check'],
#  '雷允上药业鸦胆子油口服乳液': ['producer'],
#  '肥大细胞白血病': ['disease'],
#  '金刚藤咀嚼片': ['drug'],
#  '吉林巨仁堂感冒清胶囊': ['producer'],
#  '摇摆步态': ['symptom'],
#  '小儿大动脉转位': ['disease'],
#  '亚急性结节性游走性脂膜炎': ['disease'],
#  '水牛角浓缩粉': ['drug'],
#  '广西圣康妇炎舒片': ['producer'],
#  '盖扶': ['producer'],
#  '云中制药氢氯噻嗪片': ['producer'],
#  '乐易扶': ['producer'],
#  '蜕膜残留': ['symptom'],
#  '疑病症': ['disease', 'symptom'],
#  '银耳莲子羹': ['food'],
#  '腰椎间盘突出': ['disease', 'symptom'],
#  '神水藏药十八味欧曲丸': ['producer'],
#  '河北天成羧甲司坦片': ['producer'],
#  '肥儿糖浆': ['drug'],
#  '腹痛伴恶心、呕吐': ['symptom'],
#  '香菇扒菜心': ['food'],
#  '少突胶质细胞瘤': ['disease'],
#  '头皮瘙痒剧烈并有血痂': ['symptom'],
#  '泄殖腔外翻': ['disease'],
#  '鲜肉锅贴': ['food'],
#  '龙须面': ['food'],
#  '单纯性外阴阴道念珠菌病': ['disease'],
#  '杭州国光胰岛素注射液': ['producer'],
#  '颈椎分节异常': ['symptom'],
#  '梅毒性葡萄膜炎': ['disease'],
#  '颈静脉回流试验': ['check'],
#  '压力和体位性多汗': ['symptom'],
#  '双皮鲫鱼': ['food'],
#  '注射用英夫利西单抗': ['drug'],
#  '亚邦盐酸左氧氟沙星胶囊': ['producer'],
#  '肛管括约肌横断': ['symptom'],
#  '南京白敬宇阿司匹林肠溶片': ['producer'],
#  '扳机指的弹响': ['symptom'],
#  '芝麻贡菜': ['food'],
#  '四川天德琥乙红霉素颗粒': ['producer'],
#  '鸡蛋炒面': ['food'],
#  '上海雷允上药业百蕊片': ['producer'],
#  '锦州紫金紫归治裂膏': ['producer'],
#  '维胺酯胶丸': ['drug'],
#  '复发性坏死性黏膜周围炎': ['disease'],
#  '角膜病灶刮片': ['check'],
#  '石家庄康力谷维素片': ['producer'],
#  '尿沉渣管型检查': ['check'],
#  '罗汉果金银菜柿饼汤': ['food'],
#  '美多丽': ['producer'],
#  '抗流行性出血热病毒抗体（EHF-AB）': ['check'],
#  '小肠扭转': ['disease'],
#  '浆膜腔积液葡萄糖': ['check'],
#  '赖诺普利片': ['drug'],
#  '荆州津奉麝香壮骨膏': ['producer'],
#  '遗传性凝血酶原缺乏': ['disease'],
#  '常药叶酸片': ['producer'],
#  '肺气虚': ['disease'],
#  '妊娠时皮肤皱褶...': ['symptom'],
#  '谓屏': ['producer'],
#  '森澳欣': ['producer'],
#  '江西南昌桑海钻山风糖浆': ['producer'],
#  '大网膜粘连综合征': ['disease'],
#  '安徽新和成皖南哈西奈德乳膏': ['producer'],
#  '沙参玉竹猪肺汤': ['food'],
#  '沈阳光大注射用胸腺肽': ['producer'],
#  '长生基因药业注射用重组人干': ['producer'],
#  '非典': ['disease'],
#  '团癣': ['disease'],
#  '湖南恒生注射用硝普钠': ['producer'],
#  '晨牌药业乳核内消颗粒': ['producer'],
#  '胃窦动力低下': ['symptom'],
#  '色素性皮肤病': ['disease'],
#  '炸咖喱鳕鱼': ['food'],
#  '马利兰': ['producer'],
#  '小儿肠病性肢端皮炎': ['disease'],
#  '北京万生药业阿仑膦酸钠片': ['producer'],
#  '面部畸形': ['symptom'],
#  '血清铁饱和度': ['check'],
#  '心音遥远': ['symptom'],
#  '甲硝唑维B6片': ['drug'],
#  '华典醋酸环丙孕酮片': ['producer'],
#  '肌肉发育不良': ['symptom'],
#  '输卵管妊娠': ['disease'],
#  '依赖公式化': ['symptom'],
#  '髋关节弹响试验': ['check'],
#  '性交晕厥': ['disease'],
#  '淋球菌免疫学检测': ['check'],
#  '五景药业色甘酸钠滴眼液': ['producer'],
#  '华典米非司酮片': ['producer'],
#  '遗传性硬化性皮肤异色症': ['disease'],
#  '康惠制药擦癣药水': ['producer'],
#  '妇科超声检查': ['check'],
#  '热毒冲心': ['disease'],
#  '益富清': ['producer'],
#  '烂桃样血痰': ['symptom'],
#  '耳前庭听觉失衡': ['symptom'],
#  '小儿红白血病': ['disease'],
#  '湖北康正克林霉素磷酸酯凝胶': ['producer'],
#  '贵州圣济堂盐酸二甲双胍肠溶': ['producer'],
#  '开放性神经管缺陷': ['symptom'],
#  '山西德元堂接骨续筋片': ['producer'],
#  '骨神经鞘瘤': ['disease'],
#  '自身免疫性孕酮性皮炎': ['disease'],
#  '股动脉损伤': ['disease'],
#  '黑龙江天龙克林霉素磷酸酯凝': ['producer'],
#  '气管间隙形成肿块': ['symptom'],
#  '山西津华晖星卡托普利片': ['producer'],
#  '血清r-谷氨酰基转移酶': ['check'],
#  '小肠造影': ['check'],
#  '旭东海普碘解磷定注射液': ['producer'],
#  '异丙醇试验': ['check'],
#  '海南制药厂甘露聚糖肽口服溶': ['producer'],
#  '肾复康片': ['drug'],
#  '指甲呈现黑色': ['symptom'],
#  '继发性失眠': ['symptom'],
#  '心脏停搏': ['symptom'],
#  '呼吸内科': ['department'],
#  '椎管内脊膜瘤': ['disease'],
#  '养阴清肺丸': ['drug'],
#  '上海世康特卡托普利片': ['producer'],
#  '星宝清咽片': ['producer'],
#  '广州珠江制药六合维生素丸': ['producer'],
#  '吉林集安益盛呋塞米注射液': ['producer'],
#  '消肿痔疮片': ['drug'],
#  '唾液皮质醇': ['check'],
#  '血小板无力症': ['disease'],
#  '德国礼达迈之灵片': ['producer'],
#  '大东方药业调经养颜片': ['producer'],
#  '重庆青阳盐酸奥洛他定片': ['producer'],
#  '山西太原甲硝唑维B6片': ['producer'],
#  '益脑宁片': ['drug'],
#  '黑龙江格润吡拉西坦注射液': ['producer'],
#  '海带炖鲫鱼': ['food'],
#  '脚后跟长骨刺': ['symptom'],
#  '应激反应及适应障碍': ['disease'],
#  '第一生化鲑降钙素注射液': ['producer'],
#  '陈李济壮腰健肾丸': ['producer'],
#  '汗液电解质检查': ['check'],
#  '普尔丁肺宁片': ['producer'],
#  '新华制药布洛芬片': ['producer'],
#  '多发性硬化': ['disease'],
#  '捷凝': ['producer'],
#  '猪肉丸子汤': ['food'],
#  '脊柱、脊髓损伤': ['disease'],
#  '子宫直肠窝积液': ['symptom'],
#  '广东华南双氯芬酸钠肠溶片': ['producer'],
#  '合肥华威药业克林霉素甲硝唑': ['producer'],
#  '重庆康刻尔茴三硫片': ['producer'],
#  '盆炎清栓': ['drug'],
#  '江苏淮安双鹤苦参碱氯化钠注': ['producer'],
#  '咽反射': ['symptom'],
#  '江西南昌济生双氯芬酸钠肠溶': ['producer'],
#  '海口奇力盐酸左氧氟沙星胶囊': ['producer'],
#  '中间葡萄膜炎': ['disease'],
#  '间质膀胱炎局限外阴炎和脱屑性阴道炎综合征': ['disease'],
#  '电阻抗体积描记检查': ['check'],
#  '贵妃鸡翅': ['food'],
#  '单核细胞白血病': ['disease'],
#  '鱼蛋豆芽汤': ['food'],
#  '耳流脓': ['symptom'],
#  '运佳黄浦聚维酮碘溶液': ['producer'],
#  '麻风性角膜病变': ['disease'],
#  '千金协力药业尼群地平片': ['producer'],
#  '侧腹壁或后腰部有压痛': ['symptom'],
#  '平光制药依托红霉素片': ['producer'],
#  '白细胞葡萄糖-6-磷酸脱氢酶缺乏症': ['disease'],
#  '慢性湿疹样变': ['symptom'],
#  '酱猪排骨': ['food'],
#  '江苏奥赛康注射用甲氨蝶呤': ['producer'],
#  '促卵泡激素（FSH）': ['check'],
#  '扶娃葡萄糖酸钙锌口服溶液': ['producer'],
#  '山西振东安特盐酸左旋咪唑片': ['producer'],
#  '指节垫': ['disease', 'symptom'],
#  '同德药业利多卡因氯己定气雾': ['producer'],
#  '无名指不明原因疼痛': ['symptom'],
#  '核桃天麻炖草鱼': ['food'],
#  '成都锦华盐酸小檗碱片': ['producer'],
#  '安徽新和成皖南复方醋酸地塞': ['producer'],
#  '溃疡性结肠炎': ['disease'],
#  '吉林鹿王利巴韦林含片': ['producer'],
#  '广东康奇力参三七伤药胶囊': ['producer'],
#  '猪心莲子汤': ['food'],
#  '信谊醋酸氢化可的松片': ['producer'],
#  '扑翼样震颤': ['symptom'],
#  '脂蛋白肾小球病': ['disease'],
#  '白果鸡汤': ['food'],
#  '海南慧谷利巴韦林颗粒': ['producer'],
#  '常州康普甲氧氯普胺片': ['producer'],
#  '紫鑫药业萆薢分清丸': ['producer'],
#  '干烧冬笋令': ['food'],
#  '脊柱破坏': ['symptom'],
#  '尿多巴胺': ['check'],
#  '圣特记清火栀麦片': ['producer'],
#  '浙江医药乙酰螺旋霉素片': ['producer'],
#  '湖南方盛人工牛黄甲硝唑胶囊': ['producer'],
#  '莱姆心脏炎': ['disease'],
#  '卵巢肿瘤破裂': ['disease'],
#  '丹参益心胶囊': ['drug'],
#  '破伤风人免疫球蛋白': ['drug', 'producer'],
#  '假日心脏综合征': ['symptom'],
#  '凉瓜黄豆猪肉煲': ['food'],
#  '联合免疫缺陷病': ['disease'],
#  '云鹏盐酸普萘洛尔片': ['producer'],
#  '湖南洞庭氟哌啶醇注射液': ['producer'],
#  '血清锂': ['check'],
#  '豆纹动脉闭塞': ['symptom'],
#  '尿镉': ['check'],
#  '长春长红藻酸双酯钠片': ['producer'],
#  '桡管综合征': ['disease'],
#  '妊娠相关血浆蛋白A': ['check'],
#  '北京同仁堂通窍耳聋丸': ['producer'],
#  '辉南辉发参茸强肾片': ['producer'],
#  '卵巢纤维组织来源肿瘤': ['disease'],
#  '江苏天士力溴丙胺太林片': ['producer'],
#  '酩酊感': ['symptom'],
#  '鼻咽肉瘤': ['disease'],
#  '康惠制药保胎无忧胶囊': ['producer'],
#  '民泰药业盐酸妥洛特罗片': ['producer'],
#  '气短': ['symptom'],
#  '骨关节炎': ['disease'],
#  '协和制药血尿胶囊': ['producer'],
#  '绪络菱盐酸丁咯地尔片': ['producer'],
#  '急性化脓性腮腺炎': ['disease'],
#  '运佳黄浦复方醋酸地塞米松乳': ['producer'],
#  '血清脂蛋白-α': ['check'],
#  '尿妊娠试验阳性': ['symptom'],
#  '人工流产术后出血': ['symptom'],
#  '广西万通婴儿健脾散': ['producer'],
#  '金陵南京金陵脉络宁注射液': ['producer'],
#  '血清冷球蛋白（CG）': ['check'],
#  '广东环球制药茶碱缓释片': ['producer'],
#  '泉奇': ['producer'],
#  '普华制药环磷腺苷葡胺注射液': ['producer'],
#  '灵康制药注射用果糖二磷酸钠': ['producer'],
#  '拌蓑衣黄瓜': ['food'],
#  '蜂窝肺综合征': ['disease'],
#  '老专家骨刺丸': ['producer'],
#  '小儿药物性皮炎': ['disease'],
#  '双鹤药业': ['producer'],
#  '长春天诚强力康颗粒': ['producer'],
#  '东芝堂小儿奇应丸': ['producer'],
#  '小儿呕吐': ['disease'],
#  '金太阳生化乙酰谷酰胺注射液': ['producer'],
#  '猪肉蛋卷': ['food'],
#  '莼菜粥': ['food'],
#  '肉丝榨菜汤': ['food'],
#  '老年休克': ['disease'],
#  '桔汁白菜': ['food'],
#  '老年人原发性骨髓纤维化': ['disease'],
#  '安理申': ['producer'],
#  '肢体增长、增粗过度': ['symptom'],
#  '希望制药维A酸乳膏': ['producer'],
#  '胆囊壁毛糙': ['symptom'],
#  '间歇性失忆': ['symptom'],
#  '继发性系统性淀粉样变': ['disease'],
#  '蝶鞍变形': ['symptom'],
#  '万通复升药业关节止痛膏': ['producer'],
#  '南京海辰注射用盐酸甲氯芬酯': ['producer'],
#  '舌苔薄白': ['symptom'],
#  '卓峰氧氟沙星滴眼液': ['producer'],
#  '氨基比林咖啡因片': ['drug'],
#  '金针菇炖鸡': ['food'],
#  '黄焖泥鳅': ['food'],
#  '缺血性肠绞痛': ['disease'],
#  '排水样血性大便': ['symptom'],
#  '睫状环阻滞性青光眼': ['disease'],
#  '银杏叶提取物注射液': ['drug'],
#  '鲜肝薯糊': ['food'],
#  '滋养细胞肿瘤': ['disease'],
#  '黄瓜': ['food'],
#  '博祥药业骨炎灵片': ['producer'],
#  '哈药三精制药诺捷乙酰螺旋霉': ['producer'],
#  '妊娠高血压综合征': ['disease'],
#  '美味鸡粥': ['food'],
#  '世康特硫软膏': ['producer'],
#  '赛得': ['producer'],
#  '毒毛花苷K注射液': ['drug'],
#  '华太': ['producer'],
#  '香蕉豆沙酸奶汁': ['food'],
#  '远策素': ['producer'],
#  '泪液乳酸脱氢酶': ['check'],
#  '康缘桂枝茯苓胶囊': ['producer'],
#  '西安自力活血止痛散': ['producer'],
#  '运动神经元病': ['disease'],
#  '毛孢子菌病': ['disease'],
#  '沈阳红药乳癖消片': ['producer'],
#  '陕西东科心欣舒胶囊': ['producer'],
#  '堪萨斯分枝杆菌感染': ['disease'],
#  '半月板损伤的体征': ['check'],
#  '鲜冬笋拌鸡丝': ['food'],
#  '瘦肉田鸡汤': ['food'],
#  '生地煲鸭蛋': ['food'],
#  '炒麦芽肉片汤': ['food'],
#  '痔疮外洗药': ['drug'],
#  '脾紫癜': ['symptom'],
#  '鑫惠药业叶酸片': ['producer'],
#  '金甲排石胶囊': ['drug'],
#  '青雪白癜风丸': ['producer'],
#  '维奥欣薯蓣皂苷片': ['producer'],
#  '心正药业消肿片': ['producer'],
#  '河南雪樱花盐酸吗啉胍片': ['producer'],
#  '青海晨菲注射用头孢噻肟钠': ['producer'],
#  '全血细胞计数': ['check'],
#  '阿斯匹林不耐受三联症': ['disease'],
#  '白云山何济公硼酸软膏': ['producer'],
#  '肺炎': ['disease'],
#  '海鹤板蓝根颗粒': ['producer'],
#  '甘笋酸梅汤': ['food'],
#  '心率增快': ['symptom'],
#  '腹部外形检查': ['check'],
#  '江西广信三七片': ['producer'],
#  '泌尿生殖系放线菌病': ['disease'],
#  '手下垂时皮肤呈灰蓝色': ['symptom'],
#  '反射性呕吐': ['symptom'],
#  '花红药业养血当归糖浆': ['producer'],
#  '吉林利华制药阿莫西林胶囊': ['producer'],
#  '北京同仁堂三七片': ['producer'],
#  '普恩复': ['producer'],
#  '硫酸庆大霉素颗粒': ['drug'],
#  '河南百年康鑫龙胆泻肝丸': ['producer'],
#  '广西灵峰药业妇康宁片': ['producer'],
#  '绝经期盆腔脏器脱垂': ['disease'],
#  '河北恒祥扁鹊制药安胎丸': ['producer'],
#  '荷叶丸': ['drug'],
#  '反复抽搐': ['symptom'],
#  '牙齿形态异常': ['symptom'],
#  '鞍山九天复方醋酸地塞米松乳': ['producer'],
#  '广东希埃医药锝Tc': ['producer'],
#  '湖北襄阳隆中石淋通颗粒': ['producer'],
#  '信谊天平硫酸锌片': ['producer'],
#  '广东嘉应吐泻肚痛胶囊': ['producer'],
#  '猪里脊肉': ['food'],
#  '鼻痒': ['symptom'],
#  '长春海外制药桃红清血片': ['producer'],
#  '陕西方舟氨咖甘片': ['producer'],
#  '聪而高智杞颗粒': ['producer'],
#  '可维加': ['producer'],
#  '福州海王福药三尖杉酯碱注射': ['producer'],
#  '肩峰下撞击征': ['disease'],
#  '鼎恒升清咽片': ['producer'],
#  '外伤性硬膜下积液': ['disease'],
#  '参芪健胃颗粒': ['drug'],
#  '山西振东泰盛氨茶碱片': ['producer'],
#  '太原制药脑络通胶囊': ['producer'],
#  '生殖器外伤': ['symptom'],
#  '尿钙': ['check'],
#  '热溶血试验': ['check'],
#  '红太阳舒筋定痛片': ['producer'],
#  '江西铜鼓仁和清热解毒颗粒': ['producer'],
#  '莴笋叶豆腐羹': ['food'],
#  '卡波西水痘样疹': ['disease'],
#  '山药炖牛肉': ['food'],
#  '急性肾小管间质性肾炎': ['disease'],
#  '南瓜蒸饺': ['food'],
#  '南瓜饺': ['food'],
#  '江苏鹏鹞盐酸普罗帕酮片': ['producer'],
#  '华北制药卡托普利片': ['producer'],
#  '果银耳': ['food'],
#  '三尖瓣下移': ['symptom'],
#  '如意黄柏胶囊': ['producer'],
#  '骨与关节梅毒': ['disease'],
#  '百合粳米鸡': ['food'],
#  '威尔曼制药注射用鲑鱼降钙素': ['producer'],
#  '红皮性银屑病': ['disease'],
#  '雅抒': ['producer'],
#  '妇乐冲剂': ['drug', 'producer'],
#  '海带木耳蛋汤': ['food'],
#  '金疮': ['disease'],
#  '永光制药复方托吡卡胺滴眼液': ['producer'],
#  '扭转动作': ['symptom'],
#  '湖南方盛小儿四维葡钙颗粒': ['producer'],
#  '持续性交接区折返性心动过速': ['disease'],
#  '氰化物烧伤及合并中毒': ['symptom'],
#  '脊髓小脑变性症': ['disease'],
#  '月经失调性不孕症': ['disease'],
#  '附子粥': ['food'],
#  '香菜粥': ['food'],
#  '血清锰（Mn）': ['check'],
#  ...}

# %% [markdown]
# ## 构造AC自动机，加速实体提取

# %% [markdown]
# 当知识图谱规模过大时，使用AC自动机算法，从问题中提取知识图谱中的实体，而不是用原生python的字符串方法。
#
# 扩展阅读：https://zhuanlan.zhihu.com/p/158767004

# %%
'''构造AC自动机，加速过滤'''
def build_actree(wordlist):
    actree = ahocorasick.Automaton()
    for index, word in enumerate(wordlist):
        actree.add_word(word, (index, word))
    actree.make_automaton()
    return actree

# %%
# 构造AC自动机
region_tree = build_actree(list(region_words))

# %%
region_tree

# %%
'血常规' in region_tree
# Out:
# True

# %%
region_tree.get('血常规')
# Out:
# (6828, '血常规')

# %%
'学习' in region_tree
# Out:
# False

# %%
region_tree.get('学习')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34720\3245028584.py in <module>
# ----> 1 region_tree.get('学习')
#
# KeyError:

# %% [markdown]
# ## 任务一：提取问题相关实体及其类别

# %%
question = '肺气肿和百日咳要做血常规吗'

# %%
question_entity = []
for each in region_tree.iter(question):
    print(each)
    entity = each[1][1]
    question_entity.append(entity)
print(question_entity)
# Out:
# (2, (31809, '肺气肿'))
# (6, (14226, '百日咳'))
# (11, (6828, '血常规'))
# ['肺气肿', '百日咳', '血常规']

# %%
# stop_wds = []
# # 排除字符串子串
# for wd1 in region_wds:
#     for wd2 in region_wds:
#         if wd1 in wd2 and wd1 != wd2:
#             stop_wds.append(wd1)
# print(stop_wds)
# final_wds = [each for each in region_wds if each not in stop_wds]
# final_wds

# %%
question_entity_dict = {each:wdtype_dict[each] for each in question_entity}

# %%
question_entity_dict
# Out:
# {'肺气肿': ['disease'], '百日咳': ['disease'], '血常规': ['check']}

# %%
output = {}
output['args'] = question_entity_dict

# %% [markdown]
# ## 任务一完成

# %% [markdown]
# ## 任务二：提取问题相关的待查询关系

# %% [markdown]
# ### 问题中涉及的实体类别

# %%
types = []
for each in question_entity_dict.values():
    types.extend(each)

# %%
types
# Out:
# ['disease', 'disease', 'check']

# %% [markdown]
# ### 不同提问意图的疑问词

# %%
symptom_qwds = ['症状', '表征', '现象', '症候', '表现']
cause_qwds = ['原因','成因', '为什么', '怎么会', '怎样才', '咋样才', '怎样会', '如何会', '为啥', '为何', '如何才会', '怎么才会', '会导致', '会造成']
acompany_qwds = ['并发症', '并发', '一起发生', '一并发生', '一起出现', '一并出现', '一同发生', '一同出现', '伴随发生', '伴随', '共现']
food_qwds = ['饮食', '饮用', '吃', '食', '伙食', '膳食', '喝', '菜' ,'忌口', '补品', '保健品', '食谱', '菜谱', '食用', '食物','补品']
drug_qwds = ['药', '药品', '用药', '胶囊', '口服液', '炎片']
prevent_qwds = ['预防', '防范', '抵制', '抵御', '防止','躲避','逃避','避开','免得','逃开','避开','避掉','躲开','躲掉','绕开',
                     '怎样才能不', '怎么才能不', '咋样才能不','咋才能不', '如何才能不',
                     '怎样才不', '怎么才不', '咋样才不','咋才不', '如何才不',
                     '怎样才可以不', '怎么才可以不', '咋样才可以不', '咋才可以不', '如何可以不',
                     '怎样才可不', '怎么才可不', '咋样才可不', '咋才可不', '如何可不']
lasttime_qwds = ['周期', '多久', '多长时间', '多少时间', '几天', '几年', '多少天', '多少小时', '几个小时', '多少年']
cureway_qwds = ['怎么治疗', '如何医治', '怎么医治', '怎么治', '怎么医', '如何治', '医治方式', '疗法', '咋治', '怎么办', '咋办', '咋治']
cureprob_qwds = ['多大概率能治好', '多大几率能治好', '治好希望大么', '几率', '几成', '比例', '可能性', '能治', '可治', '可以治', '可以医']
easyget_qwds = ['易感人群', '容易感染', '易发人群', '什么人', '哪些人', '感染', '染上', '得上']
check_qwds = ['检查', '检查项目', '查出', '检查', '测出', '试出']
belong_qwds = ['属于什么科', '属于', '什么科', '科室']
cure_qwds = ['治疗什么', '治啥', '治疗啥', '医治啥', '治愈啥', '主治啥', '主治什么', '有什么用', '有何用', '用处', '用途', '有什么好处', '有什么益处', '有何益处', '用来', '用来做啥', '用来作甚', '需要', '要']

# %%
def check_words(words, question):
    # 疑问词是否出现在提问中
    for word in words:
        if word in question:
            # print(word + ' 出现在提问中')
            return True
    return False

# %%
# question_type = 'others'
question_types = []

# 疾病-症状
if check_words(symptom_qwds, question) and ('disease' in types):
    question_type = 'disease_symptom'
    question_types.append(question_type)
    
# 症状-疾病
if check_words(symptom_qwds, question) and ('symptom' in types):
    question_type = 'symptom_disease'
    question_types.append(question_type)
    
# 疾病-病因
if check_words(cause_qwds, question) and ('disease' in types):
    question_type = 'disease_cause'
    question_types.append(question_type)

# 疾病-并发症
if check_words(acompany_qwds, question) and ('disease' in types):
    question_type = 'disease_acompany'
    question_types.append(question_type)

# 疾病-可以吃/不可以吃
if check_words(food_qwds, question) and 'disease' in types:
    deny_status = check_words(deny_words, question)
    if deny_status:
        question_type = 'disease_not_food'
    else:
        question_type = 'disease_do_food'
    question_types.append(question_type)
    
# 可以吃/不可以吃-疾病
if check_words(food_qwds+cure_qwds, question) and 'food' in types:
    deny_status = check_words(deny_words, question)
    if deny_status:
        question_type = 'food_not_disease'
    else:
        question_type = 'food_do_disease'
    question_types.append(question_type)
    
# 疾病-药物
if check_words(drug_qwds, question) and 'disease' in types:
    question_type = 'disease_drug'
    question_types.append(question_type)
    
# 药物-疾病
if check_words(cure_qwds, question) and 'drug' in types:
    question_type = 'drug_disease'
    question_types.append(question_type)
    
# 疾病-检查
if check_words(check_qwds, question) and 'disease' in types:
    question_type = 'disease_check'
    question_types.append(question_type)
    
# 检查-疾病
if check_words(check_qwds+cure_qwds, question) and 'check' in types:
    question_type = 'check_disease'
    question_types.append(question_type)
    
#　疾病-预防措施
if check_words(prevent_qwds, question) and 'disease' in types:
    question_type = 'disease_prevent'
    question_types.append(question_type)
    
# 疾病-疗程
if check_words(lasttime_qwds, question) and 'disease' in types:
    question_type = 'disease_lasttime'
    question_types.append(question_type)

# 疾病-疗法
if check_words(cureway_qwds, question) and 'disease' in types:
    question_type = 'disease_cureway'
    question_types.append(question_type)

# 疾病-治愈率
if check_words(cureprob_qwds, question) and 'disease' in types:
    question_type = 'disease_cureprob'
    question_types.append(question_type)

# 疾病-易感人群
if check_words(easyget_qwds, question) and 'disease' in types :
    question_type = 'disease_easyget'
    question_types.append(question_type)

# %%
question_types
# Out:
# ['check_disease']

# %%
# 若没有查到相关的外部查询信息，那么则将该疾病的描述信息返回
if question_types == [] and 'disease' in types:
    question_types = ['disease_desc']

# 若没有查到相关的外部查询信息，那么则将该疾病的描述信息返回
if question_types == [] and 'symptom' in types:
    question_types = ['symptom_disease']

# 将多个分类结果进行合并处理，组装成一个字典
output['question_types'] = question_types

# %%
output
# Out:
# {'args': {'肺气肿': ['disease'], '百日咳': ['disease'], '血常规': ['check']},
#  'question_types': ['check_disease']}
