# %% [markdown]
# # 问答机器人-从问题中提取相关实体和关系
#
# [同济子豪兄](https://space.bilibili.com/1900783) 2022-6-25

# %% [markdown]
# ## 导入工具包

# %%
import os
import ahocorasick
from tqdm import tqdm

# %% [markdown]
# ## 进入主目录

# %%
os.chdir('..')

# %%
cur_dir = os.getcwd()

# %% [markdown]
# ## 载入所有特征词

# %%
#　特征词txt文件路径
disease_path = os.path.join(cur_dir, 'dict/disease.txt')
department_path = os.path.join(cur_dir, 'dict/department.txt')
check_path = os.path.join(cur_dir, 'dict/check.txt')
drug_path = os.path.join(cur_dir, 'dict/drug.txt')
food_path = os.path.join(cur_dir, 'dict/food.txt')
producer_path = os.path.join(cur_dir, 'dict/producer.txt')
symptom_path = os.path.join(cur_dir, 'dict/symptom.txt')
deny_path = os.path.join(cur_dir, 'dict/deny.txt')

# %%
# 加载特征词
disease_wds = [i.strip() for i in open(disease_path,encoding="utf-8") if i.strip()]
department_wds = [i.strip() for i in open(department_path,encoding="utf-8") if i.strip()]
check_wds = [i.strip() for i in open(check_path,encoding="utf-8") if i.strip()]
drug_wds = [i.strip() for i in open(drug_path,encoding="utf-8") if i.strip()]
food_wds = [i.strip() for i in open(food_path,encoding="utf-8") if i.strip()]
producer_wds = [i.strip() for i in open(producer_path,encoding="utf-8") if i.strip()]
symptom_wds = [i.strip() for i in open(symptom_path,encoding="utf-8") if i.strip()]
region_words = set(disease_wds + department_wds + check_wds + drug_wds + food_wds + producer_wds + symptom_wds)
deny_words = [i.strip() for i in open(deny_path,encoding="utf-8") if i.strip()]

# %% [markdown]
# ## 所有实体对应的类型

# %%
wdtype_dict = dict()
for word in tqdm(region_words):
    wdtype_dict[word] = []
    if word in disease_wds:
        wdtype_dict[word].append('disease')
    if word in department_wds:
        wdtype_dict[word].append('department')
    if word in check_wds:
        wdtype_dict[word].append('check')
    if word in drug_wds:
        wdtype_dict[word].append('drug')
    if word in food_wds:
        wdtype_dict[word].append('food')
    if word in symptom_wds:
        wdtype_dict[word].append('symptom')
    if word in producer_wds:
        wdtype_dict[word].append('producer')
# Out:
# 100%|██████████| 43430/43430 [00:37<00:00, 1144.86it/s]

# %%
wdtype_dict
# Out:
# {'科洛曲片': ['drug'],
#  '白云峰双氯芬酸钠肠溶片': ['producer'],
#  '特发性黄斑部前膜': ['disease'],
#  '硝酸咪康唑栓': ['drug'],
#  '虎驹乙肝胶囊': ['drug'],
#  '田螺': ['food'],
#  'C3肾炎因子(C3Nef)': ['check'],
#  '肾上腺肿瘤': ['disease'],
#  '氟米龙滴眼液': ['drug'],
#  '宏仁堂养血生发胶囊': ['producer'],
#  '皇象铁力蓝天吡拉西坦片': ['producer'],
#  '言语功能的部分丧失': ['symptom'],
#  '扬州中宝药业硫酸镁注射液': ['producer'],
#  '尿氯': ['check'],
#  '贞蓉丹合剂': ['drug'],
#  '血清性荨麻疹': ['disease'],
#  '八珍片': ['drug'],
#  '猪血黄花菜': ['food'],
#  '支气管腺瘤': ['disease'],
#  '陕西东泰制药止痛化癥片': ['producer'],
#  '同济堂胶体果胶铋胶囊': ['producer'],
#  '胱氨酸储积症': ['symptom'],
#  '鼻衂': ['symptom'],
#  '静脉萎陷': ['symptom'],
#  '尤脱欣': ['producer'],
#  '男性更年期综合症': ['disease'],
#  '德众羚羊感冒片': ['producer'],
#  '太原制药阿司匹林肠溶片': ['producer'],
#  '福尔马林中毒': ['disease'],
#  '唐山利康制药醋酸曲安奈德尿': ['producer'],
#  '肘外侧夜间痛': ['symptom'],
#  '恒瑞医药氯化钠注射液': ['producer'],
#  '消朦胶囊': ['drug'],
#  '万德制药人工牛黄甲硝唑胶囊': ['producer'],
#  '播散性复发性漏斗部毛囊炎': ['disease'],
#  '艾力达': ['producer'],
#  '滑膜炎颗粒': ['drug', 'producer'],
#  '鼻孔干疼': ['symptom'],
#  '髌骨疼痛': ['symptom'],
#  '健民大鹏体外培育牛黄': ['producer'],
#  '奥托康制药巯嘌呤片': ['producer'],
#  '持续性咳嗽': ['symptom'],
#  '菊花黄鱼羹': ['food'],
#  '房室折返性心动过速': ['disease'],
#  '早饱': ['symptom'],
#  '百维药业乳酶生片': ['producer'],
#  '胃潴留': ['disease'],
#  '模仿性自动症': ['symptom'],
#  '指甲宽而短(宽...': ['symptom'],
#  '氟氯西林钠胶囊': ['drug'],
#  '嘉健盐酸倍他司汀片': ['producer'],
#  '新生儿低镁血症': ['disease'],
#  '东康药业盐酸吗啉胍滴眼液': ['producer'],
#  '北京同仁堂补中益气丸': ['producer'],
#  '骨纤维异样增殖症': ['disease'],
#  '禾丰盐酸维拉帕米注射液': ['producer'],
#  '菠菜肉丝汤面': ['food'],
#  '角膜脱落': ['symptom'],
#  '虹膜表面形成灰...': ['symptom'],
#  '烟草依赖综合症': ['disease'],
#  '成都锦华土霉素片': ['producer'],
#  '小儿中暑和暑热症': ['disease'],
#  '抗平滑肌抗体（ASMA）': ['check'],
#  '康定金珠小金丸': ['producer'],
#  '北京中新盐酸小檗碱片': ['producer'],
#  '白带pH值': ['check'],
#  '肺和胸膜视诊': ['check'],
#  '上海信谊陈香露白露片': ['producer'],
#  '通和制药阿昔洛韦分散片': ['producer'],
#  '逆行胰胆管造影（ERCP）': ['check'],
#  '老年人高血压': ['disease'],
#  '鼻部检查': ['check'],
#  '混合性厌氧菌感染': ['disease'],
#  '河南信心小儿麻甘颗粒': ['producer'],
#  '丹东宏业氨肽素片': ['producer'],
#  '山药饼': ['food'],
#  '湖南中和氟尿嘧啶口服乳': ['producer'],
#  '广东三才诺氟沙星胶囊': ['producer'],
#  '热性荨麻疹': ['disease'],
#  '蠕形螨检查': ['check'],
#  '安场鞣酸苦参碱胶囊': ['producer'],
#  '山东中泰羚羊感冒片': ['producer'],
#  '拉莫三嗪片': ['drug'],
#  '善存银片': ['drug'],
#  '阴茎头包皮炎': ['disease'],
#  '子宫收缩过强': ['disease'],
#  '电子皮镜': ['check'],
#  '血液分析仪检查': ['check'],
#  '潜江制药马来酸噻吗洛尔滴眼': ['producer'],
#  '云南云河清肺抑火片': ['producer'],
#  '儿童不敢平卧睡觉': ['symptom'],
#  '磷中毒': ['disease'],
#  '仁民药业盐酸哌甲酯片': ['producer'],
#  '海鹤利胆片': ['producer'],
#  '中西制药磷酸伯氨喹片': ['producer'],
#  '上肢麻木': ['symptom'],
#  '鼻中隔血肿及脓肿': ['disease'],
#  '舌体深裂': ['symptom'],
#  '干眼': ['disease'],
#  '西安利君九维片': ['producer'],
#  '肱动脉损伤': ['disease'],
#  '哈森为舒硫辛酸注射液': ['producer'],
#  '小儿渗出性多形性红斑': ['disease'],
#  '奇特朱砂安神丸': ['producer'],
#  '网状青斑': ['disease', 'symptom'],
#  '甲型肝炎抗体': ['check'],
#  '西博特欣': ['producer'],
#  '浙江医药葡萄糖氯化钠注射液': ['producer'],
#  '先天性马蹄内翻足': ['disease'],
#  '绝经后白带增多': ['symptom'],
#  '糖原累积症': ['disease'],
#  '鼻源性头痛': ['disease'],
#  '全葡萄膜炎': ['disease'],
#  '小儿慢性胰腺炎': ['disease'],
#  '小儿湿疹': ['disease', 'symptom'],
#  '痢疾': ['disease', 'symptom'],
#  '辽宁金丹加味逍遥丸': ['producer'],
#  '薄菊粥': ['food'],
#  '昆仑维吾尔药业复方驱虫斑鸠': ['producer'],
#  '根尖周病': ['disease'],
#  '葵花药业人工牛黄甲硝唑胶囊': ['producer'],
#  '蜂蜜萝卜汁': ['food'],
#  '急性呼吸困难': ['symptom'],
#  '负荷试验脑血流灌注显像': ['check'],
#  '毒蕈碱样症状': ['symptom'],
#  '肝功能异常': ['symptom'],
#  '常州制药吡拉西坦注射液': ['producer'],
#  '京卫制药米诺地尔喷雾剂': ['producer'],
#  '下肢肿胀和乏力': ['symptom'],
#  '尿道口疼': ['symptom'],
#  '组织多肽抗原': ['check'],
#  '子宫颈活检': ['check'],
#  '鹏鹞药业奥美拉唑肠溶胶囊': ['producer'],
#  '恩华药业舒必利片': ['producer'],
#  '巨大胎儿': ['disease'],
#  '小白菜拌海苔': ['food'],
#  '石药欧意注射用硫酸链霉素': ['producer'],
#  '痘疤': ['symptom'],
#  '恒丹头孢地尼胶囊': ['producer'],
#  '维U铝镁双层片': ['drug'],
#  '卵巢囊肿蒂扭转': ['disease'],
#  '真菌性尿路感染': ['disease'],
#  '卡前列素氨丁三醇注射液': ['drug'],
#  '山东华鲁甲硝唑葡萄糖注射液': ['producer'],
#  '排尿困难及尿潴留': ['symptom'],
#  '太阳穴胀痛': ['symptom'],
#  '黑龙江天龙复方小儿退热栓': ['producer'],
#  '猪带绦虫病': ['disease'],
#  '摩擦型性变态': ['symptom'],
#  '广东华南乙酰螺旋霉素片': ['producer'],
#  '十味诃子片': ['drug'],
#  '康圣堂藿香正气水': ['producer'],
#  '酒精中毒性幻觉症': ['symptom'],
#  '北京悦康凯悦注射用青霉素钠': ['producer'],
#  '陕西盘龙接骨续筋片': ['producer'],
#  '长期使用皮质类...': ['symptom'],
#  'IgG抗B-效价测定': ['check'],
#  '先天性梅毒性肝硬化': ['disease'],
#  '严力达氟罗沙星分散片': ['producer'],
#  '黄芪茶': ['food'],
#  '肺地丝菌病': ['disease'],
#  '氢化可的松注射液': ['drug', 'producer'],
#  '永治化痔胶囊': ['producer'],
#  '安道生': ['producer'],
#  '精索增粗肿胀': ['symptom'],
#  '颌骨囊肿': ['disease', 'symptom'],
#  '恒瑞医药丙戊酸钠片': ['producer'],
#  '肝脾肿大': ['symptom'],
#  '银鱼羊肉粥': ['food'],
#  '虫草老鸭汤': ['food'],
#  '触电': ['disease'],
#  '王老吉保济丸': ['producer'],
#  '食管蠕动功能减弱': ['symptom'],
#  '粪便白细胞': ['check'],
#  '香蕉拌桃片': ['food'],
#  '优球蛋白的溶解时间': ['check'],
#  '脏器变小': ['symptom'],
#  '北海阳光药业盐酸地芬尼多片': ['producer'],
#  '拔丝番茄': ['food'],
#  '持续性交接区折返性心动过速': ['disease'],
#  '杭州华东医药康润垂盆草颗粒': ['producer'],
#  '肛泰栓': ['drug'],
#  '足踝部光滑圆形的包块': ['symptom'],
#  '吉春制药牛黄解毒丸': ['producer'],
#  '上山虎麝香壮骨膏': ['producer'],
#  '精子运动轨迹分析': ['check'],
#  '肝癌': ['disease'],
#  '妈咪爱': ['producer'],
#  '先天性肾上腺皮质增生症': ['disease'],
#  '上海衡山富马酸酮替芬胶囊': ['producer'],
#  '血红蛋白C病': ['disease'],
#  '睾丸微小': ['symptom'],
#  '莲藕黄豆炖排骨': ['food'],
#  '鸡肉炖苁蓉': ['food'],
#  '哈尔滨力强小儿暖脐膏': ['producer'],
#  '脐血流检查': ['check'],
#  '幼年型关节强硬性脊椎炎': ['disease'],
#  '弘旭光': ['producer'],
#  '茄子肉丁': ['food'],
#  '发菜煲瘦肉汤': ['food'],
#  '川贝枇杷糖浆': ['drug'],
#  '一格制药人胎盘片': ['producer'],
#  '泌尿生殖系滴虫病': ['disease'],
#  '多抗甘露聚糖肽胶囊': ['producer'],
#  '尼群地平片': ['drug'],
#  '耳道异物': ['symptom'],
#  '修正复方胆通胶囊': ['producer'],
#  '拔毛狂': ['disease'],
#  '山药': ['food'],
#  '血红蛋白电泳': ['check'],
#  '注射用头孢哌酮钠': ['drug', 'producer'],
#  '北京健都麝香接骨胶囊': ['producer'],
#  '百合拌金针菇': ['food'],
#  '头孢克肟片': ['drug'],
#  '邦止林新': ['producer'],
#  '汇仁药业阿奇霉素片': ['producer'],
#  '高免疫球蛋白E综合征': ['disease'],
#  '三爱药业毛冬青片': ['producer'],
#  '长春海外制药舒神灵胶囊': ['producer'],
#  '血疸': ['disease'],
#  '器械性食管损伤': ['disease'],
#  '萝卜丝带鱼': ['food'],
#  '咽部异感症': ['disease'],
#  '矽肺': ['disease'],
#  '择泰': ['producer'],
#  '爱普森药业丙谷胺片': ['producer'],
#  '乐康-美的澜制药递法明片': ['producer'],
#  '脑膨出': ['disease'],
#  '胸痛伴冷汗': ['symptom'],
#  '胸壁血管充盈': ['symptom'],
#  '海王福药复方甲苯咪唑片': ['producer'],
#  '魔芋豆腐': ['food'],
#  '遂成药业亚硫酸氢钠甲萘醌注': ['producer'],
#  '嗜皮菌病': ['disease'],
#  '泪液乳铁蛋白': ['check'],
#  '华中药业甲硝唑片': ['producer'],
#  '泪腺炎': ['disease'],
#  '腹部叩诊': ['check'],
#  '端坐呼吸': ['symptom'],
#  '婴儿体重增长过快': ['symptom'],
#  '重庆迪康长江羧甲司坦片': ['producer'],
#  '震荡性神经受累': ['symptom'],
#  '酒泉大得利注射用胰激肽原酶': ['producer'],
#  '右胸痛': ['symptom'],
#  '震颤性肌强直，...': ['symptom'],
#  '熊胆痔疮膏': ['drug'],
#  '脂溢性角化病': ['disease'],
#  '特发性滴状色素减少症': ['disease'],
#  '华润紫竹药业维生素D2片': ['producer'],
#  '雪菜叉烧包': ['food'],
#  '天津天药药业醋酸地塞米松片': ['producer'],
#  '睾丸癌': ['disease'],
#  '尿黑酸': ['symptom'],
#  '葱白红枣汤': ['food'],
#  '硝酸异山梨酯片': ['drug'],
#  '东乐盐酸黄酮哌酯片': ['producer'],
#  '复方青黛胶囊': ['drug'],
#  '云南万裕盐酸非索非那定片': ['producer'],
#  '槐花豆腐汤': ['food'],
#  '专注达': ['producer'],
#  '百岁行药业唐草片': ['producer'],
#  '罗欣药业西洛他唑片': ['producer'],
#  '尿石通丸': ['drug'],
#  '茄酱菜花': ['food'],
#  '华南药业卡托普利片': ['producer'],
#  '大连金石滩硬脂酸红霉素片': ['producer'],
#  '注射用胰激肽原酶': ['drug'],
#  '喉火器伤': ['disease'],
#  '鼻后滴漏综合症': ['disease'],
#  '菠菜炒豆芽': ['food'],
#  '维宏': ['producer'],
#  '陕西东泰翁沥通胶囊': ['producer'],
#  '胃容纳性减弱': ['symptom'],
#  '先天性睾丸发育不全': ['disease'],
#  '玻璃体积血': ['disease'],
#  '山药枸杞蒸鸡': ['food'],
#  '广州白云山天心三磷酸腺苷二': ['producer'],
#  '颅骨连续性中断': ['symptom'],
#  '小儿韦格纳肉芽肿': ['disease'],
#  '妊娠高血压疾病': ['disease'],
#  '太宝制药归脾丸': ['producer'],
#  '胸腔积液临床化学检查': ['check'],
#  '血清γ-谷氨酰转肽酶同工酶': ['check'],
#  '山东仁和堂盐酸普罗帕酮片': ['producer'],
#  '蜜橘银耳汤': ['food'],
#  '惠州中药黄柏胶囊': ['producer'],
#  '皮肤病血毒丸': ['drug'],
#  '山西振东安特盐酸左旋咪唑片': ['producer'],
#  '肝脏外伤': ['disease'],
#  '云岗制药维生素C片': ['producer'],
#  '本真药业千喜胶囊': ['producer'],
#  '辰欣药业哈西奈德溶液': ['producer'],
#  '云南曲靖溃疡胶囊': ['producer'],
#  '济源济世药业补中益气丸': ['producer'],
#  '肾绞痛': ['disease'],
#  '天津创新药业罗红霉素片': ['producer'],
#  '伯尔定': ['producer'],
#  '海力生角鲨烯胶丸': ['producer'],
#  '上海中西甲巯咪唑片': ['producer'],
#  '氟哌噻吨美利曲辛片': ['drug'],
#  '神经症': ['disease'],
#  '骨膜反应': ['symptom'],
#  '金爵复方蛤青胶囊': ['producer'],
#  '阻塞性肺气肿': ['disease'],
#  '烫伤油': ['drug'],
#  '牙髓炎': ['disease'],
#  '胆管良性狭窄': ['disease'],
#  '结肠破裂': ['disease'],
#  '青鹏膏剂': ['drug'],
#  '华龙注射用胸腺五肽': ['producer'],
#  '新生儿出血性大肠杆菌肠炎': ['disease'],
#  '大峻药业荡石片': ['producer'],
#  '新生儿红细胞增多症-高黏滞度综合征': ['disease'],
#  '盐酸伊达比星胶囊': ['drug'],
#  '肿瘤性心包炎': ['disease'],
#  '胃液气味': ['check'],
#  '拔丝山慈姑': ['food'],
#  '猪小肠': ['food'],
#  '乐美奇阿奇霉素分散片': ['producer'],
#  '韭菜炒羊肝': ['food'],
#  '粪便嵌塞': ['symptom'],
#  '上海华源注射用胸腺五肽': ['producer'],
#  '心前区隆起': ['symptom'],
#  '性发育慢': ['symptom'],
#  '福建太平洋制药酞丁安乳膏': ['producer'],
#  '注射用放线菌素D': ['drug'],
#  '昆明积大注射用生长抑素': ['producer'],
#  '面肌萎缩': ['symptom'],
#  '鞘膜积水': ['symptom'],
#  '山药饺': ['food'],
#  '局限性肌张力障碍': ['symptom'],
#  '松毛虫病骨关节病': ['disease'],
#  '两眼上视障碍': ['symptom'],
#  '福建古田磺胺甲噁唑片': ['producer'],
#  '河北巨龙药业大山楂丸': ['producer'],
#  '消结安口服液': ['drug'],
#  '猪肉大葱锅贴': ['food'],
#  '必与': ['producer'],
#  '陕西康惠骨刺胶囊': ['producer'],
#  '分水岭区脑梗死': ['disease'],
#  '桔梗花生米': ['food'],
#  '食管压迫型颈椎病': ['disease'],
#  '两肺弥漫或散在...': ['symptom'],
#  '威尔曼制药阿莫西林克拉维酸': ['producer'],
#  '福建福抗注射用头孢美唑钠': ['producer'],
#  '中丹制药风油精': ['producer'],
#  '小儿家族性复发性血尿综合征': ['disease'],
#  '葫芦娃独一味软胶囊': ['producer'],
#  '顽固性心功能不全': ['symptom'],
#  '丙硫异烟胺肠溶片': ['drug'],
#  '八味秦皮丸': ['drug'],
#  '仁源堂益视颗粒': ['producer'],
#  '阿根廷出血热': ['disease'],
#  '白马妇炎康复胶囊': ['producer'],
#  '花地甲硝唑氯己定洗剂': ['producer'],
#  '尿液臭味': ['symptom'],
#  '小牛血去蛋白提取物眼用凝胶': ['drug'],
#  '精神分裂症': ['disease'],
#  '弓形体病性巩膜炎': ['disease'],
#  '假性肠梗阻': ['disease'],
#  '重庆康刻尔茴三硫片': ['producer'],
#  '泰恩康制药香荷止痒软膏': ['producer'],
#  '活动盲肠综合征': ['disease'],
#  '脑发育不良': ['disease'],
#  '大德鲜益母草胶囊': ['producer'],
#  '吉林敖东大连托西酸舒他西林': ['producer'],
#  '落臂试验': ['check'],
#  '脐带血流': ['symptom'],
#  '津华晖星曲克芦丁片': ['producer'],
#  '河南老君堂龟甲胶': ['producer'],
#  '麝香狗皮膏': ['drug'],
#  '甲状腺弥漫性病变': ['disease'],
#  '放射性心包炎': ['disease'],
#  '清芬': ['producer'],
#  '广东万年青复方首乌补液': ['producer'],
#  '明华赖氨葡锌颗粒': ['producer'],
#  '痰液中细胞分类': ['check'],
#  '香油柿子椒': ['food'],
#  '武汉爱民氨甲环酸注射液': ['producer'],
#  '小儿慢性肺炎': ['disease'],
#  '胃泌素': ['check'],
#  '什锦黄瓜卷': ['food'],
#  '日抒尿素维E乳膏': ['producer'],
#  '千禾痫愈胶囊': ['producer'],
#  '鼻粘膜苍白水肿': ['symptom'],
#  '江中药业乳酸菌素片': ['producer'],
#  '万灵阿苯达唑片': ['producer'],
#  '维生素D2注射液': ['drug'],
#  '华立金港吡拉西坦注射液': ['producer'],
#  '手指发绀或坏死': ['symptom'],
#  '精液颜色': ['check'],
#  '济民可信药业小儿热咳口服液': ['producer'],
#  '天洋制药补中益气丸': ['producer'],
#  '注射用酚磺乙胺': ['drug'],
#  '30R': ['drug'],
#  '三才石岐制药阿莫西林胶囊': ['producer'],
#  '三味清热止痒洗剂': ['drug'],
#  '尿道瘘': ['symptom'],
#  '东康药业马来酸噻吗洛尔滴眼': ['producer'],
#  '尿道结节': ['symptom'],
#  '肩胛背神经卡压症': ['disease'],
#  '白细胞介素5（iL-5）': ['check'],
#  '复方片仔癀含片': ['drug'],
#  '依普比善': ['producer'],
#  '昆明赛诺制药益脉康片': ['producer'],
#  '美联药业抗宫炎片': ['producer'],
#  '惠氏制药愈酚溴新口服溶液': ['producer'],
#  '类风湿因子（RF）': ['check'],
#  '腹部透视': ['check'],
#  '新疆国药小儿生血糖浆': ['producer'],
#  '青胡萝卜排骨汤': ['food'],
#  '四川升和紫杉醇注射液': ['producer'],
#  '小儿周期性低血钾性麻痹': ['disease'],
#  '珍珠三鲜汤': ['food'],
#  '山东惠诺环磷腺苷葡胺注射液': ['producer'],
#  '蔡氏五宝体外培育牛黄': ['producer'],
#  '金银花苦瓜汤': ['food'],
#  '芝麻芹菜段': ['food'],
#  '陕西君寿堂滋补生发片': ['producer'],
#  '酱黄瓜': ['food'],
#  '鸡蓉豆腐': ['food'],
#  '小肠造影': ['check'],
#  '康惠制药宫颈癌片': ['producer'],
#  '果酱蛋卷': ['food'],
#  '复方硝酸溶液': ['drug', 'producer'],
#  '小儿出血性疾病': ['disease'],
#  '寒湿困脾': ['disease'],
#  '南光注射用甲泼尼龙琥珀酸钠': ['producer'],
#  '老年人高脂血症': ['disease'],
#  '颅骨巨细胞瘤': ['disease'],
#  '吡啶斯的明兴奋GH试验': ['check'],
#  '柿子': ['food'],
#  '小网膜囊疝': ['disease'],
#  '山药炖鲤鱼': ['food'],
#  '克拉霉素缓释片': ['drug'],
#  '小儿自身免疫性淋巴细胞增生综合征': ['disease'],
#  '腰大肌刺激试验': ['check'],
#  '诺百益胞磷胆碱钠片': ['producer'],
#  '济丰药业阿莫西林颗粒': ['producer'],
#  '溴吡斯的明片': ['drug'],
#  '川抗制药吗替麦考酚酯分散片': ['producer'],
#  '小儿原发性腹膜炎': ['disease'],
#  '小儿中耳炎': ['disease'],
#  '天星制药鼻渊片': ['producer'],
#  '上海长征富民硫酸镁葡萄糖注': ['producer'],
#  '发作性嗜睡强食综合征': ['disease'],
#  '心肌顿抑': ['symptom'],
#  '注射用盐酸多柔比星': ['drug'],
#  '温经活血片': ['drug'],
#  '强力定眩片': ['drug'],
#  '山西普德注射用葡醛酸钠': ['producer'],
#  '小儿斜视': ['disease'],
#  '注射用氨甲环酸': ['drug'],
#  '普德药业注射用异环磷酰胺': ['producer'],
#  '注射用头孢美唑钠': ['drug'],
#  '江西新赣江通便灵胶囊': ['producer'],
#  '平消片': ['drug'],
#  '城市药业溴丙胺太林片': ['producer'],
#  '禁水加压素试验': ['check'],
#  '神经源性膀胱': ['disease'],
#  '恒瑞制药盐酸舍曲林片': ['producer'],
#  '益佰制药硫酸锌口服溶液': ['producer'],
#  '骨髓红细胞系统': ['check'],
#  '金耀药业酮洛芬凝胶': ['producer'],
#  '胡萝卜山楂汁': ['food'],
#  '扶尔': ['producer'],
#  '四肢瘫痪': ['symptom'],
#  '非普拉宗片': ['drug'],
#  '香油苦瓜': ['food'],
#  '万德制药盐酸奈福泮片': ['producer'],
#  '苏州三药盐酸克林霉素胶囊': ['producer'],
#  '肾创伤': ['disease'],
#  '湖南科伦制药注射用硝普钠': ['producer'],
#  '丽珠制药盐酸西替利嗪片': ['producer'],
#  '肝海绵状血管瘤': ['disease'],
#  '挤压泪囊试验': ['check'],
#  '森林脑炎': ['disease'],
#  '复旦复华氯唑沙宗片': ['producer'],
#  '喉插管损伤': ['disease'],
#  '江苏普华克胜熊去氧胆酸片': ['producer'],
#  '茄汁鸡腿': ['food'],
#  '斯必克': ['producer'],
#  '特灵眼药': ['drug'],
#  '银黄颗粒': ['drug'],
#  '湖北科田林旦乳膏': ['producer'],
#  '芹菜红枣汤': ['food'],
#  '甲状软骨下可触...': ['symptom'],
#  '踝反射': ['check'],
#  '红枣菊花粥': ['food'],
#  '呼吸道合胞病毒抗体': ['check'],
#  '水晶猕猴桃': ['food'],
#  '番茄黄瓜汁': ['food'],
#  '知爱': ['producer'],
#  '横纹肌肉瘤': ['disease'],
#  '食管外压和牵拉': ['disease'],
#  '广州白云山和记黄埔中药健脾': ['producer'],
#  '内脏利什曼病': ['disease'],
#  '摩擦黑变病': ['disease'],
#  '同仁堂制药厂小儿牛黄散': ['producer'],
#  '憩室出血': ['symptom'],
#  '齐力佳乌苯美司胶囊': ['producer'],
#  '山东方健麻黄止嗽丸': ['producer'],
#  '湖北科益兰索拉唑片': ['producer'],
#  '整肠生': ['producer'],
#  '钙激发试验': ['check'],
#  '红细胞5＇-嘧啶核苷酸酶': ['check'],
#  '六安华源制药盐酸氨溴索葡萄': ['producer'],
#  '西藏甘露八味沉香丸': ['producer'],
#  '舍悦': ['producer'],
#  '海南制药一厂盐酸胺碘酮胶囊': ['producer'],
#  '昆明积大阿莫西林颗粒': ['producer'],
#  '辽源誉隆亚东消痔栓': ['producer'],
#  '磷酸肌酸激酶': ['check'],
#  '福寿堂银黄颗粒': ['producer'],
#  '冻干': ['drug'],
#  '注射用奥沙利铂': ['drug'],
#  '海南制药硫酸庆大霉素注射液': ['producer'],
#  '阴雨天颈肩背部酸痛': ['symptom'],
#  '结合胆红素(SDB,DBIL)': ['check'],
#  '脂性渐进性坏死': ['disease'],
#  '贵州同济堂四环素片': ['producer'],
#  '苹果雪梨生鱼汤': ['food'],
#  '石药唐威三黄片': ['producer'],
#  '慢性扁桃体炎': ['disease'],
#  '罗汉果': ['food'],
#  '东丰药业抑亢丸': ['producer'],
#  '罗盖全': ['producer'],
#  '四肢抽搐': ['symptom'],
#  '勒夫勒心内膜炎': ['disease'],
#  '远景康业曲匹布通片': ['producer'],
#  '薄荷绿豆汤': ['food'],
#  '达芬霖': ['producer'],
#  'pH4': ['drug'],
#  '吉林长恒维D2磷酸氢钙片': ['producer'],
#  '哈药六厂对乙酰氨基酚片': ['producer'],
#  '眼底无红光反射': ['symptom'],
#  '淀粉样变性周围神经病': ['disease'],
#  '悦康药业注射用头孢曲松钠': ['producer'],
#  '冬笋土鸡煲': ['food'],
#  '月劳病': ['disease'],
#  '江苏精华制药王氏保赤丸': ['producer'],
#  '仁民药业赖氨葡锌片': ['producer'],
#  '男性化': ['symptom'],
#  '花粉过敏性哮喘': ['disease'],
#  '云南植物药业天麻素片': ['producer'],
#  '白云山医诺氟沙星胶囊': ['producer'],
#  '天天明制药氧氟沙星滴眼液': ['producer'],
#  '颌骨错位': ['symptom'],
#  '三木制药灵仙跌打片': ['producer'],
#  '北京同仁堂活血止痛散': ['producer'],
#  '海鲸药业维生素A软胶囊': ['producer'],
#  '赤小豆粥': ['food'],
#  '同仁堂制药厂加味青娥丸': ['producer'],
#  '胡萝卜菠菜汁': ['food'],
#  '东北制药甘露聚糖肽口服溶液': ['producer'],
#  '晨牌药业夏枯草颗粒': ['producer'],
#  '东药阿奇霉素胶囊': ['producer'],
#  '石家庄御生堂安神补心丸': ['producer'],
#  '西安必康制药琥乙红霉素片': ['producer'],
#  '当归羊肉火锅': ['food'],
#  '前列腺病': ['disease'],
#  '江西心诚蒲公英颗粒': ['producer'],
#  '环磷腺苷葡胺葡萄糖注射液': ['drug'],
#  '精液细胞': ['check'],
#  '山东仁和堂双嘧达莫片': ['producer'],
#  '山东华信吡拉西坦注射液': ['producer'],
#  '脑脊液细胞计数': ['check'],
#  '卡马西平片': ['drug'],
#  '广州欧化盐酸洛美沙星片': ['producer'],
#  '迪维佳多维铁口服溶液': ['producer'],
#  '四川升和通脉颗粒': ['producer'],
#  '祛痰止咳颗粒': ['drug'],
#  '掌骨指数及指骨...': ['symptom'],
#  '老年妇女乳房增大': ['symptom'],
#  '老年人急性淋巴细胞白血病': ['disease'],
#  '螨皮炎': ['disease'],
#  '睑结膜的巨大乳头': ['symptom'],
#  '窥阴癖': ['disease'],
#  '芝士菜花': ['food'],
#  '广西梧州生化丸': ['producer'],
#  '重庆华邦制药复方樟脑乳膏': ['producer'],
#  '黄体生成素（LH）': ['check'],
#  '湖南德海增光胶囊': ['producer'],
#  '血清醛缩酶': ['check'],
#  '太原药业维生素B6片': ['producer'],
#  '眼球偏斜': ['symptom'],
#  '天津生物眼氨肽注射液': ['producer'],
#  '显锋科技阿莫西林胶囊': ['producer'],
#  '维阿堂复方卡力孜然酊': ['producer'],
#  '小儿缺铁性贫血': ['disease'],
#  '海神同洲盐酸左氧氟沙星胶囊': ['producer'],
#  '蜜桃果泥': ['food'],
#  '星安忆': ['producer'],
#  '片仔癀复方片仔癀痔疮软膏': ['producer'],
#  '本溪仙草堂小金丸': ['producer'],
#  '北京中惠盐酸二甲双胍肠溶片': ['producer'],
#  '沈阳一药注射用青霉素钠': ['producer'],
#  '广西浦北三磷酸腺苷二钠片': ['producer'],
#  '常州制药布洛芬片': ['producer'],
#  '屈肌紧张试验': ['check'],
#  '哈药三精黑河盐酸金刚烷胺颗': ['producer'],
#  '第一生化维生素K1注射液': ['producer'],
#  '睫状充血': ['symptom'],
#  '尿三胆检查': ['check'],
#  '百咳静糖浆': ['drug'],
#  '天禾迪赛诺苦参碱氯化钠注射': ['producer'],
#  '坐骨神经痛': ['disease', 'symptom'],
#  '松鹿制药养阴清肺口服液': ['producer'],
#  '寄生虫检查的浓聚法': ['check'],
#  '信谊布地奈德气雾剂': ['producer'],
#  '金华火腿': ['food'],
#  '广州白云山明兴鸦胆子油乳注': ['producer'],
#  '小儿室性心动过速': ['disease'],
#  '丘脑下部损伤': ['disease'],
#  '皮肤软骨瘤': ['disease'],
#  '苦木注射液': ['drug'],
#  '交宁替莫唑胺胶囊': ['producer'],
#  '痃癖': ['disease'],
#  '葡萄糖氯化钠注射液': ['drug'],
#  '京舒阿托伐他汀钙分散片': ['producer'],
#  '青海晨菲注射用头孢噻肟钠': ['producer'],
#  '普美拉泰': ['producer'],
#  '上唇变薄': ['symptom'],
#  '吉通药业降脂宁颗粒': ['producer'],
#  '华南药业复方磺胺甲噁唑片': ['producer'],
#  '菜花': ['food'],
#  '北京顺鑫祥云小儿清解颗粒': ['producer'],
#  '咖喱鸡肉包': ['food'],
#  '茄汁烘猪肝': ['food'],
#  '老鸭绿豆汤': ['food'],
#  '江苏黄河药业阿替洛尔片': ['producer'],
#  '良性纤维组织细胞瘤': ['disease'],
#  '凉冻菠萝酪': ['food'],
#  '气管软化试验': ['check'],
#  '指甲呈筒形': ['symptom'],
#  '小儿混合性结缔组织病': ['disease'],
#  '三门峡乳酶生片': ['producer'],
#  '海南华拓天涯苦参碱氯化钠注': ['producer'],
#  '颈根部斜方肌及...': ['symptom'],
#  '浙江瑞新维生素C片': ['producer'],
#  '兴贝维生素AD滴剂': ['producer'],
#  '食管病': ['disease'],
#  '迪瑞制药维生素C咀嚼片': ['producer'],
#  '子宫腺肌病': ['disease'],
#  '无睾丸': ['symptom'],
#  '广西古方积雪苷胶囊': ['producer'],
#  '外阴浸润性鳞癌': ['disease'],
#  '三元痛血康胶囊': ['producer'],
#  '新疆特丰大蒜肠溶片': ['producer'],
#  '山西正元盛邦白癜风丸': ['producer'],
#  '小儿病态窦房结综合征': ['disease'],
#  '葵花药业集团重庆小葵花儿童制': ['producer'],
#  '接触性荨麻疹': ['disease'],
#  '孚茵': ['producer'],
#  '头孢呋辛酯颗粒': ['drug'],
#  '东海维生素E软胶囊': ['producer'],
#  '原发性急性闭角型青光眼': ['disease'],
#  '哮喘持续状态': ['disease'],
#  '起点': ['symptom'],
#  '性心理不成熟': ['symptom'],
#  '豆腐海带汤': ['food'],
#  '康缘药业桂枝茯苓胶囊': ['producer'],
#  '浙江得恩德制药盐酸左氧氟沙': ['producer'],
#  'HLA定型': ['check'],
#  '北京京丰制药集团卡托普利片': ['producer'],
#  '结节': ['symptom'],
#  '腹痛伴恶心、呕吐': ['symptom'],
#  '白敬宇制药盐酸左旋咪唑片': ['producer'],
#  '玉米粥': ['food'],
#  '西达本胺片': ['drug'],
#  '小儿X-连锁淋巴组织增生性疾病': ['disease'],
#  '长春海外制药桃红清血片': ['producer'],
#  '入睡幻觉': ['symptom'],
#  '甲胎蛋白增高': ['symptom'],
#  '颈椎退化': ['symptom'],
#  '山东华信制药藻酸双酯钠注射': ['producer'],
#  '过敏性紫癜': ['disease'],
#  '股神经卡压综合征': ['disease'],
#  '巨仁堂通窍鼻炎片': ['producer'],
#  '先天性鼻咽部狭窄及闭锁': ['disease'],
#  '乳汁吸入性肺炎': ['disease'],
#  '脊突叩痛': ['symptom'],
#  '胸椎黄韧带骨化症': ['disease'],
#  '通气贮量比': ['check'],
#  '江西赣南喷托维林氯化铵糖浆': ['producer'],
#  '肛门病变': ['symptom'],
#  '持久性豆状角化过度病': ['disease'],
#  '猪肉酸菜包': ['food'],
#  '横膈低平': ['symptom'],
#  '传导阻滞': ['symptom'],
#  '一度房室传导阻滞': ['disease'],
#  '疫黄': ['disease'],
#  '小炒香干芹菜': ['food'],
#  '溶血尿毒症综合征': ['disease'],
#  '小儿结节性硬化综合征': ['disease'],
#  '钼靶摄影检查': ['check'],
#  '尿铁（Fe）': ['check'],
#  '蜘蛛痣': ['disease', 'symptom'],
#  '小儿厌食症': ['disease'],
#  '小儿支气管肺发育不全': ['disease'],
#  '蓝痣': ['disease'],
#  '伴高血压': ['symptom'],
#  '陕西东泰制药乳宁片': ['producer'],
#  '口腔科': ['department'],
#  '惠诺药业盐酸特比萘芬乳膏': ['producer'],
#  '抗人球蛋白试验': ['check'],
#  '蒜黄': ['food'],
#  '玉林消石片': ['producer'],
#  '天泰止痛化癥胶囊': ['producer'],
#  '新生儿发绀': ['symptom'],
#  '凉拌野菊花': ['food'],
#  '泛恶欲吐': ['symptom'],
#  '膝外侧韧带损伤': ['disease'],
#  '碘化油软胶囊': ['drug'],
#  '脊髓休克': ['symptom'],
#  '山东仙河夏枯草颗粒': ['producer'],
#  '长春银诺克琥乙红霉素片': ['producer'],
#  '健胃消食片': ['drug'],
#  '氟尿嘧啶注射液': ['drug'],
#  '异源内分泌综合征': ['disease'],
#  '关节镜检查': ['check'],
#  '百花牌陈香露白露片': ['producer'],
#  '脂肪尿和乳糜尿检查(Chyluria)': ['check'],
#  '脸颊发灰': ['symptom'],
#  '灰白色结节': ['symptom'],
#  '沙美特罗替卡松粉吸入剂': ['drug'],
#  '豆腐乳粥': ['food'],
#  '增殖型天疱疮': ['disease'],
#  '散结镇痛胶囊': ['drug'],
#  '江西济民可信婴儿健脾颗粒': ['producer'],
#  '长段升主动脉发育不全': ['symptom'],
#  '睑板腺癌': ['disease'],
#  '小儿弹性假黄瘤': ['disease'],
#  '黄瓜木耳汤': ['food'],
#  '足趾屈曲挛缩': ['symptom'],
#  '鳞屑': ['symptom'],
#  '体外异种授精实验': ['check'],
#  '猪肝菠菜粥': ['food'],
#  '成都一药氢溴酸樟柳碱注射液': ['producer'],
#  '指间关节不能屈曲': ['symptom'],
#  '红糖姜汤': ['food'],
#  '龟头出血': ['symptom'],
#  '胃切除后吸收不良综合征': ['disease'],
#  '芝麻南瓜饼': ['food'],
#  '正清制药甲氨蝶呤片': ['producer'],
#  '信谊溴新斯的明片': ['producer'],
#  '果汁豆腐': ['food'],
#  '九惠制药毛冬青胶囊': ['producer'],
#  '东陵药业益肝灵片': ['producer'],
#  '夏都苦参碱氯化钠注射液': ['producer'],
#  '胸部B超': ['check'],
#  '地红霉素肠溶胶囊': ['drug'],
#  '脊髓灰质炎': ['disease'],
#  '放射性周围神经病': ['disease'],
#  '眼功能检查': ['check'],
#  '突发的右侧心衰': ['symptom'],
#  '吉林正和药业接骨片': ['producer'],
#  '肩胛带的肌肉不发达': ['symptom'],
#  '浙江震元醋酸奥曲肽注射液': ['producer'],
#  '眼球会聚功能麻...': ['symptom'],
#  '老年人大肠肿瘤': ['disease'],
#  '发菜豆腐汤': ['food'],
#  '溴丙胺太林片': ['drug'],
#  '宫缩应激试验': ['check'],
#  '血吸虫皮内试验': ['check'],
#  '吉林吉春益康胶囊': ['producer'],
#  '波顿格征': ['check'],
#  '蝰蛇毒复钙时间': ['check'],
#  '不偏向一侧，无...': ['symptom'],
#  '高颅压性脑积水': ['disease'],
#  '吉林大峻连翘败毒片': ['producer'],
#  '踝关节肿胀': ['symptom'],
#  '江西天施康中药肿节风注射液': ['producer'],
#  '骨化性肌炎': ['disease'],
#  '冬瓜肉末羹': ['food'],
#  '卓峰盐酸消旋山莨菪碱注射液': ['producer'],
#  '昼盲': ['symptom'],
#  '博恩特药业注射用醋酸亮丙瑞': ['producer'],
#  '太阳病': ['disease'],
#  '小儿烫伤': ['disease'],
#  '海王福药盐酸洛贝林注射液': ['producer'],
#  '免疫病理检查': ['check'],
#  '地中海贫血': ['disease'],
#  '小儿成骨不全': ['disease'],
#  '恶心与呕吐': ['symptom'],
#  '多毛症': ['disease'],
#  '玻片压诊法': ['check'],
#  '淋巴结-胆道综合征': ['disease'],
#  '牙齿过敏': ['disease'],
#  '前庭反射消失': ['symptom'],
#  '尿维生素B2': ['check'],
#  '色素失调症': ['disease'],
#  '吉春制药擦癣药水': ['producer'],
#  '金耀药业盐酸肾上腺素注射液': ['producer'],
#  '东泰血复生胶囊': ['producer'],
#  '小儿五维赖氨酸糖浆': ['drug'],
#  '生菜': ['food'],
#  '栗子猪肉汤': ['food'],
#  '广东环球制药复方甲苯咪唑片': ['producer'],
#  '石家康力药业西咪替丁片': ['producer'],
#  '大连美罗注射用硫酸链霉素': ['producer'],
#  '皇象铁力蓝天马来酸氯苯那敏': ['producer'],
#  '黄瓜素虾仁': ['food'],
#  '鸡蛋面': ['food'],
#  '国药集团武汉血液制品人血白': ['producer'],
#  '广东彼迪阿奇霉素分散片': ['producer'],
#  '山药炒鱼片': ['food'],
#  '过渡区R波递增不良': ['symptom'],
#  '银屑颗粒': ['drug', 'producer'],
#  '阴道上皮内瘤样变': ['disease'],
#  '背部酸痛': ['symptom'],
#  '白血病伴发的精神障碍': ['disease'],
#  '维奥制药克拉霉素胶囊': ['producer'],
#  '同济堂制药氨甲环酸片': ['producer'],
#  '膝反射': ['check'],
#  '肥膘肉': ['food'],
#  '兰陵制药硫酸镁注射液': ['producer'],
#  '蛋黄碎牛肉粥': ['food'],
#  '食道粘膜水肿充血': ['symptom'],
#  '鲜莲子青蟹羹': ['food'],
#  '倍他胡萝卜素胶丸': ['drug'],
#  '山楂': ['food'],
#  '利君制药氢化泼尼松注射液': ['producer'],
#  '湖北潜江地塞米松磷酸钠注射': ['producer'],
#  '闭塞性血栓性脉管炎': ['disease'],
#  '丹东康宁丁硼乳膏': ['producer'],
#  '牡丹江灵泰利肺片': ['producer'],
#  '武汉华龙注射用胸腺五肽': ['producer'],
#  '狂犬病人免疫球蛋白': ['drug'],
#  '股骨大粗隆结核': ['disease'],
#  '外伤性乳房血肿': ['disease'],
#  '长期使用糖皮质...': ['symptom'],
#  '一过性意识蒙眬': ['symptom'],
#  '灯盏花素片': ['drug'],
#  '御本堂药业理气化瘀口服液': ['producer'],
#  '捏鼻闭口呼气法': ['check'],
#  '反射性神经障碍症': ['disease'],
#  '山药软炸兔': ['food'],
#  '红斑型天疱疮': ['disease'],
#  '小儿偏头痛': ['disease'],
#  '小活络丸': ['drug'],
#  '民生呋喃硫胺片': ['producer'],
#  '玉米牛肉羹': ['food'],
#  '鲁抗注射用头孢哌酮钠': ['producer'],
#  '黑龙江惠美佳过氧化氢溶液': ['producer'],
#  '小儿慢性良性中性粒细胞减少症': ['disease'],
#  '上海雷允上三七片': ['producer'],
#  '湖北益康肾骨颗粒': ['producer'],
#  '通化金恺威骨刺消痛胶囊': ['producer'],
#  '华润高科茵栀黄口服液': ['producer'],
#  '天津中新健步壮骨丸': ['producer'],
#  '恶露不净': ['symptom'],
#  '血尿酸': ['check'],
#  '奇正伤湿止痛膏': ['producer'],
#  '华南药业维生素C片': ['producer'],
#  '瑞森药业至灵菌丝胶囊': ['producer'],
#  '间质性肺炎': ['disease'],
#  '江苏亚邦生缘晕可平糖浆': ['producer'],
#  '间歇性血尿': ['symptom'],
#  '奥赛托星': ['producer'],
#  '迈之灵片': ['drug'],
#  '山西太原利巴韦林注射液': ['producer'],
#  '福星生物复方奎宁注射液': ['producer'],
#  '脊髓亚急性联合变性': ['disease'],
#  '江苏瑞年前进舒必利片': ['producer'],
#  '打喷嚏时胸口疼': ['symptom'],
#  '痰有恶臭味': ['symptom'],
#  '视网膜分支动脉阻塞': ['disease'],
#  '墨鱼苦瓜': ['food'],
#  '依姆多': ['producer'],
#  '江苏亚邦爱普森普卢利沙星胶': ['producer'],
#  '气管隆突以上的损伤': ['symptom'],
#  '反应性精神病': ['disease'],
#  '复发性阿弗他溃疡': ['disease'],
#  '郑州卓峰盐酸洛美沙星滴耳液': ['producer'],
#  '浙江南洋乳酸菌素片': ['producer'],
#  '华润紫竹药业达那唑胶囊': ['producer'],
#  '气道阻力(R)': ['check'],
#  '急性闭角性青光眼': ['disease'],
#  '血浆游离血红蛋白': ['check'],
#  '眼病': ['disease'],
#  '正骨膏': ['drug'],
#  '番茄芦笋紫菜汤': ['food'],
#  '香炒胡萝卜': ['food'],
#  '步长神州制药宫瘤消胶囊': ['producer'],
#  '老年人高钙血症': ['disease'],
#  '仁和制药利巴韦林颗粒': ['producer'],
#  '国瑞脂肪乳注射液': ['producer'],
#  '胎心率异常': ['symptom'],
#  '小儿糖原贮积病Ⅳ型': ['disease'],
#  '芹菜炒鸡蛋虾仁': ['food'],
#  '耳流脓': ['symptom'],
#  '生精胶囊': ['drug'],
#  '泰康药业复方鲜竹沥液': ['producer'],
#  '风湿性心脏病': ['disease'],
#  '哈尔滨乐泰和络舒肝胶囊': ['producer'],
#  '爱咪特': ['producer'],
#  '痰呈粘液脓性': ['symptom'],
#  '跖纹': ['symptom'],
#  '房室交接区性期前收缩': ['disease'],
#  '氢溴酸加兰他敏注射液': ['drug'],
#  '北芪莲藕炖牛腩': ['food'],
#  '仙琚制药甲硫酸新斯的明注射': ['producer'],
#  '迪诺制药泮托拉唑钠肠溶胶囊': ['producer'],
#  '心火': ['symptom'],
#  '浙江圣博康双氯芬酸钠滴眼液': ['producer'],
#  '桂花鲜栗羹': ['food'],
#  '楚克五妙水仙膏': ['producer'],
#  '天朗制药消旋山莨菪碱滴眼液': ['producer'],
#  '齐都药业尼麦角林片': ['producer'],
#  '利巴韦林滴眼液': ['drug'],
#  '国药集团武汉中联四药药业羟': ['producer'],
#  '醋酸可的松注射液': ['drug'],
#  '达适兰索拉唑肠溶片': ['producer'],
#  '成都正康复方氯化钠注射液': ['producer'],
#  '海王福药阿苯达唑胶囊': ['producer'],
#  '食管恶性病变': ['symptom'],
#  '山西普德注射用复方甘草酸单': ['producer'],
#  '锋珠新': ['producer'],
#  '马鞍山天福康补中益气丸': ['producer'],
#  '白云山制药总厂奋乃静片': ['producer'],
#  '脑震荡': ['disease'],
#  '临汾宝珠甲硝唑片': ['producer'],
#  '后发性白内障': ['disease'],
#  '营养不良性皮肤钙化病': ['disease'],
#  '急性泪腺炎': ['disease'],
#  '肾虚腰痛': ['disease'],
#  '精瘀证': ['disease'],
#  '胆管结石与胆管炎': ['disease'],
#  '琥乙红霉素胶囊': ['drug'],
#  'δ-贮存池病': ['disease'],
#  '麻风病的皮内试验': ['check'],
#  '信龙牙痛灵樟脑水合氯醛酊': ['producer'],
#  '痰液中弹力纤维': ['check'],
#  '宝庆丙戊酸钠片': ['producer'],
#  '鲤鱼汤': ['food'],
#  '天阳药业盐酸左旋咪唑片': ['producer'],
#  '华兰生物狂犬病人免疫球蛋白': ['producer'],
#  '深圳国盛源复合维生素B片': ['producer'],
#  '小白菜芋头': ['food'],
#  '宫爆墨鱼仔': ['food'],
#  '盐酸吡硫醇片': ['drug'],
#  '冬瓜荷叶瘦肉汤': ['food'],
#  '东药乙酰谷酰胺注射液': ['producer'],
#  '稻农皮炎': ['disease'],
#  '大黄蛰虫丸': ['drug'],
#  '辅仁智同药业注射用卡铂': ['producer'],
#  '酱茄子': ['food'],
#  '马来酸曲美布汀片': ['drug'],
#  '视力筛查仪': ['check'],
#  '黄芪鲫鱼汤': ['food'],
#  '老年人胰腺癌': ['disease'],
#  '江苏万高产妇安颗粒': ['producer'],
#  '迪康长江制药苦参碱氯化钠注': ['producer'],
#  '陕西京西醋酸可的松片': ['producer'],
#  '眶周水肿': ['symptom'],
#  '食管失弛缓症': ['disease'],
#  '草菇煮豆腐': ['food'],
#  '卓邦溶菌酶含片': ['producer'],
#  '焦作福瑞堂盐酸二氧丙嗪颗粒': ['producer'],
#  '番茄菜花': ['food'],
#  '葡萄膜恶性黑色素瘤': ['disease'],
#  '梅子炖鸭': ['food'],
#  '永定制药百咳静糖浆': ['producer'],
#  '尿lgG': ['check'],
#  '小儿毛细支气管炎': ['disease'],
#  '腹腔脏器的叩诊': ['check'],
#  '希尔安金蝉止痒颗粒': ['producer'],
#  '咳出棕色痰栓': ['symptom'],
#  '浙江奥托康巯嘌呤片': ['producer'],
#  '白扁豆': ['food'],
#  '胰岛细胞类癌': ['disease'],
#  '清蒸鲈鱼': ['food'],
#  '玉米面（黄）': ['food'],
#  '青春期发育迟缓': ['disease'],
#  '纤维毛囊瘤': ['disease'],
#  '心室内传导阻滞': ['disease'],
#  '玉米（鲜）': ['food'],
#  '湖北老中醫复方紫参颗粒': ['producer'],
#  '血虚眩晕': ['disease'],
#  '毛孢子菌病': ['disease'],
#  '古楼羟基脲片': ['producer'],
#  '先天性椎体畸形': ['disease'],
#  '北京双吉制霉素阴道栓': ['producer'],
#  '幽门前区溃疡': ['symptom'],
#  '成都一药双氯芬酸钠肠溶片': ['producer'],
#  '散结止痛膏': ['drug'],
#  '浆细胞': ['check'],
#  '焦米粥': ['food'],
#  '浙江天瑞曲克芦丁氯化钠注射': ['producer'],
#  '广东南国甘露醇注射液': ['producer'],
#  '九明制药黄柏胶囊': ['producer'],
#  '好息达豆腐果苷片': ['producer'],
#  '广州白云山医药集团白云山何济': ['producer'],
#  '胸廓狭窄而扁': ['symptom'],
#  '结肠平滑肌瘤': ['disease'],
#  '天洋制药附子理中丸': ['producer'],
#  '抗丙型肝炎病毒IgA抗体': ['check'],
#  '黄河药业克拉霉素胶囊': ['producer'],
#  '喜安林': ['producer'],
#  ...}

# %% [markdown]
# ## 构造AC自动机，加速实体提取

# %% [markdown]
# 当知识图谱规模过大时，使用AC自动机算法，从问题中提取知识图谱中的实体，而不是用原生python的字符串方法。
#
# 扩展阅读：https://zhuanlan.zhihu.com/p/158767004

# %%
'''构造AC自动机，加速过滤'''
def build_actree(wordlist):
    actree = ahocorasick.Automaton()
    for index, word in enumerate(wordlist):
        actree.add_word(word, (index, word))
    actree.make_automaton()
    return actree

# %%
# 构造AC自动机
region_tree = build_actree(list(region_words))

# %%
region_tree

# %%
'血常规' in region_tree
# Out:
# True

# %%
region_tree.get('血常规')
# Out:
# (26332, '血常规')

# %%
'学习' in region_tree
# Out:
# False

# %%
region_tree.get('学习')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10964\3245028584.py in <module>
# ----> 1 region_tree.get('学习')
#
# KeyError:

# %% [markdown]
# ## 任务一：提取问题相关实体及其类别

# %%
question = '肺气肿和百日咳要做血常规吗'

# %%
question_entity = []
for each in region_tree.iter(question):
    print(each)
    entity = each[1][1]
    question_entity.append(entity)
print(question_entity)
# Out:
# (2, (12044, '肺气肿'))
# (6, (25971, '百日咳'))
# (11, (26332, '血常规'))
# ['肺气肿', '百日咳', '血常规']

# %%
# stop_wds = []
# # 排除字符串子串
# for wd1 in region_wds:
#     for wd2 in region_wds:
#         if wd1 in wd2 and wd1 != wd2:
#             stop_wds.append(wd1)
# print(stop_wds)
# final_wds = [each for each in region_wds if each not in stop_wds]
# final_wds

# %%
question_entity_dict = {each:wdtype_dict[each] for each in question_entity}

# %%
question_entity_dict
# Out:
# {'肺气肿': ['disease'], '百日咳': ['disease'], '血常规': ['check']}

# %%
output = {}
output['args'] = question_entity_dict

# %% [markdown]
# ## 任务一完成

# %% [markdown]
# ## 任务二：提取问题相关的待查询关系

# %% [markdown]
# ### 问题中涉及的实体类别

# %%
types = []
for each in question_entity_dict.values():
    types.extend(each)

# %%
types
# Out:
# ['disease', 'disease', 'check']

# %% [markdown]
# ### 不同提问意图的疑问词

# %%
symptom_qwds = ['症状', '表征', '现象', '症候', '表现']
cause_qwds = ['原因','成因', '为什么', '怎么会', '怎样才', '咋样才', '怎样会', '如何会', '为啥', '为何', '如何才会', '怎么才会', '会导致', '会造成']
acompany_qwds = ['并发症', '并发', '一起发生', '一并发生', '一起出现', '一并出现', '一同发生', '一同出现', '伴随发生', '伴随', '共现']
food_qwds = ['饮食', '饮用', '吃', '食', '伙食', '膳食', '喝', '菜' ,'忌口', '补品', '保健品', '食谱', '菜谱', '食用', '食物','补品']
drug_qwds = ['药', '药品', '用药', '胶囊', '口服液', '炎片']
prevent_qwds = ['预防', '防范', '抵制', '抵御', '防止','躲避','逃避','避开','免得','逃开','避开','避掉','躲开','躲掉','绕开',
                     '怎样才能不', '怎么才能不', '咋样才能不','咋才能不', '如何才能不',
                     '怎样才不', '怎么才不', '咋样才不','咋才不', '如何才不',
                     '怎样才可以不', '怎么才可以不', '咋样才可以不', '咋才可以不', '如何可以不',
                     '怎样才可不', '怎么才可不', '咋样才可不', '咋才可不', '如何可不']
lasttime_qwds = ['周期', '多久', '多长时间', '多少时间', '几天', '几年', '多少天', '多少小时', '几个小时', '多少年']
cureway_qwds = ['怎么治疗', '如何医治', '怎么医治', '怎么治', '怎么医', '如何治', '医治方式', '疗法', '咋治', '怎么办', '咋办', '咋治']
cureprob_qwds = ['多大概率能治好', '多大几率能治好', '治好希望大么', '几率', '几成', '比例', '可能性', '能治', '可治', '可以治', '可以医']
easyget_qwds = ['易感人群', '容易感染', '易发人群', '什么人', '哪些人', '感染', '染上', '得上']
check_qwds = ['检查', '检查项目', '查出', '检查', '测出', '试出']
belong_qwds = ['属于什么科', '属于', '什么科', '科室']
cure_qwds = ['治疗什么', '治啥', '治疗啥', '医治啥', '治愈啥', '主治啥', '主治什么', '有什么用', '有何用', '用处', '用途', '有什么好处', '有什么益处', '有何益处', '用来', '用来做啥', '用来作甚', '需要', '要']

# %%
def check_words(words, question):
    # 疑问词是否出现在提问中
    for word in words:
        if word in question:
            # print(word + ' 出现在提问中')
            return True
    return False

# %%
# question_type = 'others'
question_types = []

# 疾病-症状
if check_words(symptom_qwds, question) and ('disease' in types):
    question_type = 'disease_symptom'
    question_types.append(question_type)
    
# 症状-疾病
if check_words(symptom_qwds, question) and ('symptom' in types):
    question_type = 'symptom_disease'
    question_types.append(question_type)
    
# 疾病-病因
if check_words(cause_qwds, question) and ('disease' in types):
    question_type = 'disease_cause'
    question_types.append(question_type)

# 疾病-并发症
if check_words(acompany_qwds, question) and ('disease' in types):
    question_type = 'disease_acompany'
    question_types.append(question_type)

# 疾病-可以吃/不可以吃
if check_words(food_qwds, question) and 'disease' in types:
    deny_status = check_words(deny_words, question)
    if deny_status:
        question_type = 'disease_not_food'
    else:
        question_type = 'disease_do_food'
    question_types.append(question_type)
    
# 可以吃/不可以吃-疾病
if check_words(food_qwds+cure_qwds, question) and 'food' in types:
    deny_status = check_words(deny_words, question)
    if deny_status:
        question_type = 'food_not_disease'
    else:
        question_type = 'food_do_disease'
    question_types.append(question_type)
    
# 疾病-药物
if check_words(drug_qwds, question) and 'disease' in types:
    question_type = 'disease_drug'
    question_types.append(question_type)
    
# 药物-疾病
if check_words(cure_qwds, question) and 'drug' in types:
    question_type = 'drug_disease'
    question_types.append(question_type)
    
# 疾病-检查
if check_words(check_qwds, question) and 'disease' in types:
    question_type = 'disease_check'
    question_types.append(question_type)
    
# 检查-疾病
if check_words(check_qwds+cure_qwds, question) and 'check' in types:
    question_type = 'check_disease'
    question_types.append(question_type)
    
#　疾病-预防措施
if check_words(prevent_qwds, question) and 'disease' in types:
    question_type = 'disease_prevent'
    question_types.append(question_type)
    
# 疾病-疗程
if check_words(lasttime_qwds, question) and 'disease' in types:
    question_type = 'disease_lasttime'
    question_types.append(question_type)

# 疾病-疗法
if check_words(cureway_qwds, question) and 'disease' in types:
    question_type = 'disease_cureway'
    question_types.append(question_type)

# 疾病-治愈率
if check_words(cureprob_qwds, question) and 'disease' in types:
    question_type = 'disease_cureprob'
    question_types.append(question_type)

# 疾病-易感人群
if check_words(easyget_qwds, question) and 'disease' in types :
    question_type = 'disease_easyget'
    question_types.append(question_type)

# %%
question_types
# Out:
# ['check_disease']

# %%
# 若没有查到相关的外部查询信息，那么则将该疾病的描述信息返回
if question_types == [] and 'disease' in types:
    question_types = ['disease_desc']

# 若没有查到相关的外部查询信息，那么则将该疾病的描述信息返回
if question_types == [] and 'symptom' in types:
    question_types = ['symptom_disease']

# 将多个分类结果进行合并处理，组装成一个字典
output['question_types'] = question_types

# %%
output
# Out:
# {'args': {'肺气肿': ['disease'], '百日咳': ['disease'], '血常规': ['check']},
#  'question_types': ['check_disease']}
