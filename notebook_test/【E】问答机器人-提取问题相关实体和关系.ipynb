# %% [markdown]
# # 问答机器人-从问题中提取相关实体和关系
#
# [同济子豪兄](https://space.bilibili.com/1900783) 2022-6-25

# %% [markdown]
# ## 导入工具包

# %%
import os
import ahocorasick
from tqdm import tqdm

# %% [markdown]
# ## 进入主目录

# %%
os.chdir('..')

# %%
cur_dir = os.getcwd()

# %% [markdown]
# ## 载入所有特征词

# %%
#　特征词txt文件路径
disease_path = os.path.join(cur_dir, 'dict/disease.txt')
department_path = os.path.join(cur_dir, 'dict/department.txt')
check_path = os.path.join(cur_dir, 'dict/check.txt')
drug_path = os.path.join(cur_dir, 'dict/drug.txt')
food_path = os.path.join(cur_dir, 'dict/food.txt')
producer_path = os.path.join(cur_dir, 'dict/producer.txt')
symptom_path = os.path.join(cur_dir, 'dict/symptom.txt')
deny_path = os.path.join(cur_dir, 'dict/deny.txt')

# %%
# 加载特征词
disease_wds = [i.strip() for i in open(disease_path,encoding="utf-8") if i.strip()]
department_wds = [i.strip() for i in open(department_path,encoding="utf-8") if i.strip()]
check_wds = [i.strip() for i in open(check_path,encoding="utf-8") if i.strip()]
drug_wds = [i.strip() for i in open(drug_path,encoding="utf-8") if i.strip()]
food_wds = [i.strip() for i in open(food_path,encoding="utf-8") if i.strip()]
producer_wds = [i.strip() for i in open(producer_path,encoding="utf-8") if i.strip()]
symptom_wds = [i.strip() for i in open(symptom_path,encoding="utf-8") if i.strip()]
region_words = set(disease_wds + department_wds + check_wds + drug_wds + food_wds + producer_wds + symptom_wds)
deny_words = [i.strip() for i in open(deny_path,encoding="utf-8") if i.strip()]

# %%
print(len(disease_wds))
print(len(department_wds))
print(len(check_wds))
print(len(drug_wds))
print(len(food_wds))
print(len(producer_wds))
print(len(symptom_wds))
print(len(region_words))
print(len(deny_words))
# Out:
# 8807
# 54
# 3353
# 3828
# 4870
# 17201
# 5998
# 43430
# 37

# %% [markdown]
# ## 所有实体对应的类型

# %%
wdtype_dict = dict()
for word in tqdm(region_words):
    wdtype_dict[word] = []
    if word in disease_wds:
        wdtype_dict[word].append('disease')
    if word in department_wds:
        wdtype_dict[word].append('department')
    if word in check_wds:
        wdtype_dict[word].append('check')
    if word in drug_wds:
        wdtype_dict[word].append('drug')
    if word in food_wds:
        wdtype_dict[word].append('food')
    if word in symptom_wds:
        wdtype_dict[word].append('symptom')
    if word in producer_wds:
        wdtype_dict[word].append('producer')
# Out:
# 100%|██████████| 43430/43430 [00:26<00:00, 1657.77it/s]

# %%
print(len(wdtype_dict))
wdtype_dict
# Out:
# 43430
# {'胸椎畸形': ['symptom'],
#  '尿co2测定': ['check'],
#  '颈椎增生': ['symptom'],
#  '国瑞甘油果糖氯化钠注射液': ['producer'],
#  '阴道横隔': ['disease', 'symptom'],
#  '荷叶粉蒸牛肉': ['food'],
#  '鲜蚕豆紫菜汤': ['food'],
#  '特风平豨蛭络达胶囊': ['producer'],
#  '鸡汤小豆腐': ['food'],
#  '磁共振波谱分析': ['check'],
#  '二巯丁二酸胶囊': ['drug'],
#  '鸭粥': ['food'],
#  '草莓菠菜汁': ['food'],
#  '丽申宝': ['producer'],
#  '先天性髋关节外展挛缩和骨盆倾斜': ['disease'],
#  '宝珠制药肌醇烟酸酯片': ['producer'],
#  '颈椎间盘退变': ['symptom'],
#  '南国药业三磷酸腺苷二钠片': ['producer'],
#  '丹东宏业氨肽素片': ['producer'],
#  '青春发育延迟及性幼稚': ['disease'],
#  '真性菌尿': ['symptom'],
#  '齿龈肥厚': ['symptom'],
#  '威高药业二乙酰氨乙酸乙二胺': ['producer'],
#  '紫花烧伤膏': ['drug'],
#  '喷昔洛韦乳膏': ['drug'],
#  '酸性磷酸酶染色': ['check'],
#  '婴儿肠痉挛': ['disease'],
#  '美多丽': ['producer'],
#  '生发丸': ['drug'],
#  '沈阳康芝制药复方咖磷颗粒': ['producer'],
#  '北海蓝海洋消朦胶囊': ['producer'],
#  '华南药业维生素B1片': ['producer'],
#  '博士伦福瑞达牛磺酸滴眼液': ['producer'],
#  '金恒制药硫酸锌片': ['producer'],
#  '痰湿体质': ['symptom'],
#  '前庭反射消失': ['symptom'],
#  '急性肝病': ['disease'],
#  '便鲜红血呈点滴...': ['symptom'],
#  '一新制药复方硫黄乳膏': ['producer'],
#  '康力欣胶囊': ['drug'],
#  '手指和足趾无痛...': ['symptom'],
#  '眉毛外侧脱落稀疏而细': ['symptom'],
#  '鼻炎宁颗粒': ['drug', 'producer'],
#  '脑脊液氨基酸': ['check'],
#  '党参田七炖鸡': ['food'],
#  '美通制药别嘌醇片': ['producer'],
#  '空心菜排骨汤': ['food'],
#  '阿茉立': ['producer'],
#  '盐酸左布诺洛尔滴眼液': ['drug'],
#  '三色豆猪肘冬瓜汤': ['food'],
#  '西同静': ['producer'],
#  '普拉固': ['producer'],
#  '鼻翼扇动': ['symptom'],
#  '多发内生软骨瘤病': ['disease'],
#  '黄瓜玫瑰饮': ['food'],
#  '羊水尿酸': ['check'],
#  '抗甲状腺过氧化物酶自身抗体': ['check'],
#  '肛周皮肤有湿疹': ['symptom'],
#  '隐孢子虫病': ['disease'],
#  '双燕牌醋酸氟轻松乳膏': ['producer'],
#  '喉咙溃疡': ['symptom'],
#  '广东华南双氯芬酸钠肠溶片': ['producer'],
#  '站立位研磨试验': ['check'],
#  '呼吸性细支气管相关的间质性肺疾病': ['disease'],
#  '中科院医学研究所胸腺肽注射': ['producer'],
#  '南京恒生制药盐酸艾司洛尔注': ['producer'],
#  '江西南大博仕蒲公英颗粒': ['producer'],
#  '瘢痕性脱发': ['disease'],
#  '普奈新': ['producer'],
#  '先天性肌性斜颈': ['disease'],
#  '打喷嚏时胸口疼': ['symptom'],
#  '吉林特研利心丸': ['producer'],
#  '前列腺液中淀粉样体': ['check'],
#  '痰培养': ['check'],
#  '步长参仙升脉口服液': ['producer'],
#  '牛痘疫苗接种家兔炎症皮肤提取物片': ['drug'],
#  '尖锐湿疣': ['disease'],
#  '肝肾亏虚': ['symptom'],
#  '经前综合症': ['symptom'],
#  '乙型肝炎抗原抗体检测': ['check'],
#  '不能屈膝': ['symptom'],
#  '北京三联消癌平片': ['producer'],
#  'II型糖尿病': ['disease'],
#  '睾丸下降不全': ['disease'],
#  '药物性肝硬化': ['disease'],
#  '小儿尖端扭转型室性心动过速': ['disease'],
#  '干烧茄子': ['food'],
#  '四川锡成颠茄片': ['producer'],
#  '锁喉痈': ['disease'],
#  '精氨酰琥珀酸裂解酶': ['check'],
#  '四川绿叶制药乌苯美司胶囊': ['producer'],
#  '辰欣药业克霉唑乳膏': ['producer'],
#  '广东岭南注射用异环磷酰胺': ['producer'],
#  '罗汉果金银菜柿饼汤': ['food'],
#  '海正麦克丁': ['producer'],
#  '联佳': ['producer'],
#  '江西众源参茸卫生丸': ['producer'],
#  '锑中毒': ['disease'],
#  '蓝痣': ['disease'],
#  '天津金耀集团氨甲环酸注射液': ['producer'],
#  '健民药业驱白巴布期片': ['producer'],
#  '甲状腺素结合球蛋白': ['check'],
#  '百利天华脾氨肽口服冻干粉': ['producer'],
#  '庆余堂小牛血去蛋白提取物注': ['producer'],
#  '全血铁': ['check'],
#  '肝-颈静脉回流征阳性': ['symptom'],
#  '酒精中毒': ['disease'],
#  '风寒犯肺': ['disease'],
#  '金诃坐珠达西': ['producer'],
#  '珍熊胆丸': ['drug'],
#  '辽宁格林乙酰唑胺片': ['producer'],
#  '木耳烩豌豆': ['food'],
#  '舌下神经检查': ['check'],
#  '千禾乳癖舒胶囊': ['producer'],
#  '湖北益康肾骨颗粒': ['producer'],
#  '北京永康药业盐酸肾上腺素注': ['producer'],
#  '黑龙江百泰吡拉西坦片': ['producer'],
#  '同济堂制药仙灵骨葆片': ['producer'],
#  '下肢淋巴水肿': ['disease'],
#  '湖北炎黄本草济泰片': ['producer'],
#  '颈动脉搏动检查': ['check'],
#  '北京益民药业阿替洛尔片': ['producer'],
#  '桃花桂鱼': ['food'],
#  '南瓜馅水饺': ['food'],
#  'δ-贮存池病': ['disease'],
#  '上海朝晖曲安奈德益康唑乳膏': ['producer'],
#  '天舒欣康复新液': ['producer'],
#  '扬州中惠复方血栓通片': ['producer'],
#  '抗ENA抗体': ['check'],
#  '人卫牌水杨酸苯酚贴膏': ['producer'],
#  '湖北中佳酚磺乙胺注射液': ['producer'],
#  '下背部酸痛': ['symptom'],
#  '右腹痛': ['symptom'],
#  '腓总神经损害': ['disease'],
#  '熟地瑶柱牛骨汤': ['food'],
#  '职业性硬皮病': ['disease'],
#  '广东南国羧甲司坦片': ['producer'],
#  '手部伸肌腱损伤': ['disease'],
#  '天津华津溴丙胺太林片': ['producer'],
#  '肝外胆管结石': ['symptom'],
#  '三益哈西奈德溶液': ['producer'],
#  '安胃胶囊': ['drug'],
#  '北京勃然妇科分清丸': ['producer'],
#  '阑尾消炎片': ['drug'],
#  '万寿堂健肝灵胶囊': ['producer'],
#  '华山牌艾附暖宫丸': ['producer'],
#  '金峰制药盐酸氨溴索葡萄糖注': ['producer'],
#  '嘉宁健儿清解液': ['producer'],
#  '大肠梗阻': ['disease'],
#  '新乡恒久远盐酸倍他司汀片': ['producer'],
#  '宇宙脑蛋白水解物片': ['producer'],
#  '广州珠江制药复方银耳鱼肝油': ['producer'],
#  '浙江诚意维生素K1注射液': ['producer'],
#  '超级影像': ['check'],
#  '广西仁德千福制药夏桑菊颗粒': ['producer'],
#  '脉压缩小': ['symptom'],
#  '骨痹': ['symptom'],
#  '妊娠合并消化性溃疡': ['disease'],
#  '韭菜蛋丝': ['food'],
#  '南京瑞尔转移因子口服溶液': ['producer'],
#  '银屑病关节炎': ['disease'],
#  '非溃疡消化不良': ['disease'],
#  '成都倍特阿米卡星洗剂': ['producer'],
#  '膈现象': ['check'],
#  '阴结': ['disease'],
#  '普瑞巴林胶囊': ['drug'],
#  '血宁片': ['drug'],
#  '健心片': ['drug'],
#  '微达康颗粒': ['drug'],
#  '盐酸丁氯喘片': ['drug'],
#  '血虚脱发': ['symptom'],
#  '普通透视检查(透视)': ['check'],
#  '胡萝卜丁炒豌豆': ['food'],
#  '黏膜白斑': ['disease', 'symptom'],
#  '消炎止痢灵片': ['drug'],
#  '黄瓜拌鱿鱼': ['food'],
#  '桡骨小头骨骺分离': ['disease'],
#  '素三鲜豆腐汤': ['food'],
#  '白云山光华盐酸米诺环素胶囊': ['producer'],
#  '珠海联邦倍他米松乳膏': ['producer'],
#  '外生殖器畸形': ['disease'],
#  '梁河民族制药清肺抑火片': ['producer'],
#  '南京制药注射用培美曲塞二钠': ['producer'],
#  '宫颈粘液检查': ['check'],
#  '8808聚维酮碘溶液': ['producer'],
#  '鱼香鸡爪': ['food'],
#  '贵州百灵陈香露白露片': ['producer'],
#  '痢疾': ['disease', 'symptom'],
#  '羊水白细胞': ['check'],
#  '博科药业排毒清脂片': ['producer'],
#  '淮杞煲羊脑': ['food'],
#  '广西梧州注射用去水卫矛醇': ['producer'],
#  '北京紫竹硫酸镁注射液': ['producer'],
#  '胎膜早破': ['disease', 'symptom'],
#  '缺智齿': ['symptom'],
#  '高脂血症': ['disease'],
#  '民生盐酸羟甲唑啉喷雾剂': ['producer'],
#  '盖明文': ['symptom'],
#  '广东宏远药业辅酶Q10胶囊': ['producer'],
#  '维生素B1': ['check'],
#  '宫炎康颗粒': ['drug'],
#  '枸橼酸氢钾钠颗粒': ['drug'],
#  '木香顺气丸': ['drug'],
#  '产前征兆': ['symptom'],
#  '结膜异物': ['symptom'],
#  '迪耳药业多维铁口服溶液': ['producer'],
#  '耳冻伤': ['symptom'],
#  '乙型肝炎表面抗体': ['check'],
#  '妍婷苦参栓': ['producer'],
#  '凹甲': ['symptom'],
#  '九芝堂裸花紫珠片': ['producer'],
#  '粘膜萎缩': ['symptom'],
#  '麦克马瑞试验': ['check'],
#  '腰背刺痛': ['symptom'],
#  '维纯蹄甲多肽片': ['producer'],
#  '驴肉': ['food'],
#  '难治性腹水': ['symptom'],
#  '复合乳酸菌胶囊': ['drug'],
#  '垂直性忽略症': ['symptom'],
#  '唯康药业曲咪新乳膏': ['producer'],
#  '臀上皮神经干痛': ['disease'],
#  '胆囊息肉样病变': ['disease'],
#  '口腔结核性溃疡': ['disease'],
#  '呈泡沫样有腥臭味稀便': ['symptom'],
#  '乳腺纤维肉瘤': ['disease'],
#  '麦角隐亭咖啡因口服液': ['drug'],
#  '脑白质稀疏': ['symptom'],
#  '炎症性腹主动脉瘤': ['disease'],
#  '神威药业尼莫地平软胶囊': ['producer'],
#  '河南鼎昌溴丙胺太林片': ['producer'],
#  '复方硫酸新霉素滴眼液': ['drug', 'producer'],
#  '家族性黏液血管纤维瘤': ['disease'],
#  '糖原染色': ['check'],
#  '玉簪清咽十五味散': ['drug'],
#  '宛西制药知柏地黄丸': ['producer'],
#  '子宫内膜薄': ['disease'],
#  '卓坦': ['producer'],
#  '酸烧伤': ['symptom'],
#  '素焖扁豆': ['food'],
#  '乳房纤维腺瘤': ['disease'],
#  '上海现代阿奇霉素干混悬剂': ['producer'],
#  '麻风性角膜病变': ['disease'],
#  '草莓果汁': ['food'],
#  '阿迈新': ['producer'],
#  '广东南国扑米酮片': ['producer'],
#  '脊柱破坏': ['symptom'],
#  '栗子山楂羹': ['food'],
#  '乳房疼痛': ['disease', 'symptom'],
#  '清煨玉米笋': ['food'],
#  '明水药业头孢氨苄甲氧苄啶片': ['producer'],
#  '天洋制药银黄胶囊': ['producer'],
#  '南京制药注射用异环磷酰胺': ['producer'],
#  '利尔药业甘露聚糖肽胶囊': ['producer'],
#  '言克欣苦参软膏': ['producer'],
#  '持久性隆起性红斑': ['disease'],
#  '磷酸川芎嗪片': ['drug'],
#  '第一生物复方牛胎肝提取物片': ['producer'],
#  '看不到脚尖步行困难': ['symptom'],
#  '特发性室性心动过速': ['disease'],
#  '广东嘉博盐酸罗哌卡因注射液': ['producer'],
#  '绒毛膜取样术': ['check'],
#  '同仁堂牛黄清胃丸': ['producer'],
#  '西瓜霜润喉片': ['drug'],
#  '吞咽时发生晕厥': ['symptom'],
#  '石药欧意藿香正气胶囊': ['producer'],
#  '中族中药利胆排石片': ['producer'],
#  '胡萝卜炒蛋': ['food'],
#  '血管迷走性晕厥': ['symptom'],
#  '白塞病': ['disease'],
#  '畅维禧': ['producer'],
#  '华西制药消癌平糖浆': ['producer'],
#  '山西临汾氢化可的松片': ['producer'],
#  '氯氮平口腔崩解片': ['drug'],
#  '要利琴': ['symptom'],
#  '炸胡萝卜豆腐丸': ['food'],
#  '奥勃兰': ['producer'],
#  '太阳肾炎康复片': ['producer'],
#  '接触性出血': ['symptom'],
#  '脓疱性痤疮': ['symptom'],
#  '闽海药业复方桔梗止咳片': ['producer'],
#  '大连美罗拉坦前列素滴眼液': ['producer'],
#  '济仁根痛平胶囊': ['producer'],
#  '脑脊液天门冬氨酸氨基转移酶': ['check'],
#  '大肠癌': ['disease'],
#  '发菜鸡卷': ['food'],
#  '乳突': ['check'],
#  '膝关节肿胀积血': ['symptom'],
#  '江西东风药业注射用青霉素钾': ['producer'],
#  '青春期功能失调性子宫出血': ['disease'],
#  '膈下脓肿': ['disease'],
#  '颈痛胶囊': ['drug'],
#  '持续性头晕': ['symptom'],
#  '舒胆胶囊': ['drug'],
#  '湖南时代阳光夏桑菊颗粒': ['producer'],
#  '哈尔滨大洋肾复康胶囊': ['producer'],
#  '麻痹性睑外翻': ['disease'],
#  '阿米巴原虫抗体': ['check'],
#  '柠檬鹌鹑': ['food'],
#  '阿胶糯米粥': ['food'],
#  '上海和黄耳聋左慈丸': ['producer'],
#  '江苏远恒复方氯化钠滴眼液': ['producer'],
#  '血清亮氨酸氨基转肽酶（LAP）': ['check'],
#  '珍珠三鲜汤': ['food'],
#  '鼻翼边缘缺损': ['symptom'],
#  '前列腺酸性磷酸酶（PAP）': ['check'],
#  '敖康欣': ['producer'],
#  '青笋鱼丁': ['food'],
#  '老年人肺心病': ['disease'],
#  '大株红景天胶囊': ['drug'],
#  '闭经': ['disease', 'symptom'],
#  '小儿急性阑尾炎': ['disease'],
#  '宫瘤清片': ['drug'],
#  '西瓜瘦肉汤': ['food'],
#  '孔孟白带丸': ['producer'],
#  '山东圣鲁呋塞米注射液': ['producer'],
#  '草菇饺': ['food'],
#  '远大国奥仙鹿口服液': ['producer'],
#  '依生生物制药冻干人用狂犬病': ['producer'],
#  '阴道流血过多': ['symptom'],
#  '当归腹痛宁滴丸': ['drug'],
#  '红癣': ['disease'],
#  '小儿抗磷脂综合征': ['disease'],
#  '抱癖': ['symptom'],
#  '芬必得布洛芬缓释胶囊': ['producer'],
#  '头皮痣': ['disease'],
#  '龙虎龙虎人丹': ['producer'],
#  '宫颈癌片': ['drug'],
#  '汕头明治医药地喹氯铵含片': ['producer'],
#  '梅毒肾病': ['disease'],
#  '煮鸡翅拌桃仁': ['food'],
#  '桡神经损伤': ['disease'],
#  '5-羟吲哚乙酸': ['check'],
#  '面部肌肉痉挛': ['symptom'],
#  '猪脾': ['food'],
#  '情绪性胃痛': ['symptom'],
#  '足跟后凸': ['symptom'],
#  '郑州卓峰盐酸消旋山莨菪碱注': ['producer'],
#  '麦收皮炎': ['disease'],
#  '新活素': ['producer'],
#  '汗疱症': ['disease'],
#  '苦夏': ['disease'],
#  '安诺药业阿奇霉素分散片': ['producer'],
#  '盐酸肾上腺素注射液': ['drug'],
#  '夏枯草炖海带': ['food'],
#  '派瑞松': ['producer'],
#  '反复出血': ['symptom'],
#  '搏动性肿块': ['symptom'],
#  '语音震颤增强': ['symptom'],
#  '反应性精神病': ['disease'],
#  '武汉爱民烟酰胺注射液': ['producer'],
#  '化妆品的毛发损害': ['symptom'],
#  '汕头金石枸橼酸铋钾颗粒': ['producer'],
#  '晕痣': ['disease'],
#  '宫颈妊娠': ['disease'],
#  '肉桂粥': ['food'],
#  '丽珠克毒星阿昔洛韦片': ['producer'],
#  '大同利群盐酸金刚烷胺颗粒': ['producer'],
#  '间歇性失忆': ['symptom'],
#  '副肿瘤性小脑变性': ['disease'],
#  '莪术油注射液': ['drug'],
#  '欧意维生素BT片': ['producer'],
#  '胸、腰椎爆裂骨折': ['disease'],
#  '葵花药业氨甲环酸片': ['producer'],
#  '天津力生制药甲氧氯普胺片': ['producer'],
#  '谷氨酸钠注射液': ['drug'],
#  '山西千汇藻酸双酯钠片': ['producer'],
#  '湖北中佳氟康唑滴眼液': ['producer'],
#  '三原妇炎舒片': ['producer'],
#  '香雪兰苦柏止痒洗液': ['producer'],
#  '豆苗炒鸡蛋': ['food'],
#  '拌嫩香椿芽': ['food'],
#  '辅仁药业人工牛黄甲硝唑胶囊': ['producer'],
#  '细粒棘球蚴病': ['disease'],
#  '足癣': ['disease', 'symptom'],
#  '副乳乳腺癌': ['disease'],
#  '等渗尿': ['symptom'],
#  '香肥带鱼': ['food'],
#  '上海衡山熊去氧胆酸片': ['producer'],
#  '长春长庆牛磺酸滴眼液': ['producer'],
#  '口周皮炎': ['disease'],
#  '盐酸特比萘芬溶液': ['drug'],
#  '情感性心境障碍': ['disease'],
#  '血凝抑制试验': ['check'],
#  '河山胸腺肽肠溶片': ['producer'],
#  '山西天生补中益气丸': ['producer'],
#  '盐酸拓扑替康胶囊': ['drug'],
#  '镇静、安定、催眠药中毒': ['disease'],
#  '雪菜青豆韭菜豆腐汤': ['food'],
#  '心厥': ['disease'],
#  '小儿肺热咳喘颗粒': ['drug'],
#  '瓜烧白菜': ['food'],
#  '流行性角结膜炎': ['disease'],
#  '五0五止血宁胶囊': ['producer'],
#  '牙齿数目过剩': ['symptom'],
#  '御宁复方胚肝铁铵片': ['producer'],
#  '硬红斑': ['disease'],
#  '麻疹病毒抗体': ['check'],
#  '信谊天平盐酸氨溴索胶囊': ['producer'],
#  '小儿弹性假黄瘤': ['disease'],
#  '主动脉瓣狭窄合并关闭不全': ['disease'],
#  '卵巢环管状性索肿瘤': ['disease'],
#  '特异性IgE抗体': ['check'],
#  '注射用帕米膦酸二钠': ['drug'],
#  '吉林吉春肾复康胶囊': ['producer'],
#  '辽宁德善药业升提胶囊': ['producer'],
#  '肝肺综合征': ['disease'],
#  '非IgA系膜增生性肾炎': ['disease'],
#  '华北制药阿莫西林舒巴坦匹酯': ['producer'],
#  '骨炎灵片': ['drug'],
#  '羊水泡沫试验': ['check'],
#  '立健新': ['producer'],
#  '巨细胞病毒病': ['disease'],
#  '霍夫曼征': ['check'],
#  '接骨七厘片': ['drug', 'producer'],
#  '豆腐皮春卷': ['food'],
#  '内蒙古蒙药克感额日敦片': ['producer'],
#  '志远嘉宝金刚藤口服液': ['producer'],
#  '白敬宇制药维生素C片': ['producer'],
#  '人格解体': ['symptom'],
#  '气臌': ['disease'],
#  '上海上药新亚药业注射用头孢': ['producer'],
#  '间碘苄胍γ-闪烁照相': ['check'],
#  '注射用放线菌素D': ['drug'],
#  'α2-热稳定性糖蛋白': ['check'],
#  '丁酸氯倍他松乳膏': ['drug'],
#  '无锡华澳十滴水': ['producer'],
#  '上海禾丰硫酸妥布霉素注射液': ['producer'],
#  '跖反射伸性': ['symptom'],
#  '北京万生药业苯磺酸氨氯地平': ['producer'],
#  '斯达制药注射用头孢曲松钠': ['producer'],
#  '万德制药盐酸奈福泮片': ['producer'],
#  '哈药诺捷奥美拉唑肠溶胶囊': ['producer'],
#  '牙齿萌出异常': ['symptom'],
#  '广仁骨刺片': ['producer'],
#  '芝麻拌白菜丁': ['food'],
#  'CT造影扫描': ['check'],
#  '太极通天口服液': ['producer'],
#  '骨髓增生程度': ['check'],
#  '酶学检查': ['check'],
#  '浙江越翠珍珠末': ['producer'],
#  '恒和维康枸橼酸钾颗粒': ['producer'],
#  '中指不明原因痛': ['symptom'],
#  '复方青黛胶囊': ['drug'],
#  '盆腔瘀血': ['symptom'],
#  '灰白大便': ['symptom'],
#  '大便成颗粒': ['symptom'],
#  '自身免疫性甲状腺疾病相关肾病': ['disease'],
#  '小肠虚寒': ['disease'],
#  '仲景妇科养荣丸': ['producer'],
#  '指深屈肌肌力试验': ['check'],
#  '吉尔吉药业喘嗽宁片': ['producer'],
#  '粉红色泡沫样痰': ['symptom'],
#  '脓肿破入胸腔': ['symptom'],
#  '河南济源济世补中益气丸': ['producer'],
#  '酱爆海蟹': ['food'],
#  '环甲肌失去收缩...': ['symptom'],
#  '无色性色素失调症': ['disease'],
#  '红细胞电泳时间测定': ['check'],
#  '冬虫夏草田鸡腿粥': ['food'],
#  '洛莫司汀胶囊': ['drug'],
#  '糖链抗原15-3': ['check'],
#  '海南卫康注射用头孢噻肟钠': ['producer'],
#  '腓骨肌萎缩症': ['disease'],
#  '吉春制药健肝灵胶囊': ['producer'],
#  '世信药业新生化颗粒': ['producer'],
#  '尿频伴尿急和尿痛': ['symptom'],
#  '山东鑫齐小儿麻甘颗粒': ['producer'],
#  '神经性皮炎': ['disease'],
#  '乏特壶腹周围癌': ['disease'],
#  '多发性骨髓瘤': ['disease'],
#  '注射用呋塞米': ['drug'],
#  '清炖水鱼': ['food'],
#  '牙周脓肿': ['disease'],
#  '核桃天麻炖草鱼': ['food'],
#  '山东新华氨茶碱片': ['producer'],
#  '香油苦瓜': ['food'],
#  '帝玛尔藏药十三味红花丸': ['producer'],
#  '天麻素注射液': ['drug'],
#  '远景康业羟基脲片': ['producer'],
#  '司邦得制药辛伐他汀片': ['producer'],
#  '阴道炎': ['disease'],
#  '眶底爆折': ['symptom'],
#  '赛升药业注射用胸腺肽': ['producer'],
#  '桂林华信环吡酮胺乳膏': ['producer'],
#  '棘上韧带损伤': ['disease'],
#  '吉林英联生物阿魏酸钠注射液': ['producer'],
#  '东康药业复方磺胺甲噁唑片': ['producer'],
#  '酞丁安搽剂': ['drug'],
#  '足不能跖屈和内翻': ['symptom'],
#  '结肠损伤': ['disease'],
#  '苯丁酸氮芥片': ['drug'],
#  '柴胡注射液': ['drug', 'producer'],
#  '青岛双鲸维生素E胶丸': ['producer'],
#  '视束病变': ['disease'],
#  '芝芝冰黄肤乐软膏': ['producer'],
#  '常药熊去氧胆酸片': ['producer'],
#  '复方硫酸亚铁颗粒': ['drug'],
#  '泛细支气管炎': ['disease'],
#  '卵磷脂络合碘胶囊': ['drug'],
#  '天津天药药业醋酸地塞米松片': ['producer'],
#  '睾丸自我检查': ['check'],
#  '盐酸甲氯芬酯胶囊': ['drug'],
#  '桡骨远端骨折': ['disease'],
#  '虾子烧白菜头': ['food'],
#  '低钠血症': ['disease', 'symptom'],
#  '坏死性筋膜炎': ['disease', 'symptom'],
#  '西洛他唑片': ['drug', 'producer'],
#  '痛风结节': ['symptom'],
#  '幽门螺旋杆菌的免疫学检测': ['check'],
#  '白云山和黄中药毛冬青胶囊': ['producer'],
#  '输尿管梗阻': ['symptom'],
#  '江苏亚邦爱普森盐酸可乐定片': ['producer'],
#  '肾病综合征': ['disease', 'symptom'],
#  '豫西药业氯霉素片': ['producer'],
#  '老年人肺性脑病': ['disease'],
#  '发茂森除脂生发片': ['producer'],
#  '百年六福堂马来酸氯苯那敏片': ['producer'],
#  '大豆芽冬菇脚腐皮汤': ['food'],
#  '银杏叶提取物注射液': ['drug'],
#  '原发性阴道恶性淋巴瘤': ['disease'],
#  '小儿磷酸酶过少症': ['disease'],
#  '深圳同安消炎利胆片': ['producer'],
#  '君碧莎白癜风胶囊': ['producer'],
#  '曲优盐酸舍曲林片': ['producer'],
#  '狼疮带试验': ['check'],
#  '粘稠度': ['check'],
#  '产后血虚热': ['disease'],
#  '大得利制药亚硫酸氢钠甲萘醌': ['producer'],
#  '去病药业除脂生发片': ['producer'],
#  '复方双金痔疮膏': ['drug'],
#  '安道生': ['producer'],
#  '泽桂癃爽胶囊': ['drug'],
#  '皮肤脑膜瘤': ['disease'],
#  '桃仁拌莴笋': ['food'],
#  '白敬宇制药维生素B1片': ['producer'],
#  '茯苓': ['food'],
#  '康酮索': ['producer'],
#  '德源药业甲钴胺胶囊': ['producer'],
#  '好护士乳癖消胶囊': ['producer'],
#  '邯郸康业复方硫酸新霉素滴眼': ['producer'],
#  '豆腐脑': ['food'],
#  '金世制药复方环磷酰胺片': ['producer'],
#  '额叶癫痫岛盖发作': ['symptom'],
#  '海南利能康泰注射用核黄素磷': ['producer'],
#  '江西希尔康泰丹曲林钠胶囊': ['producer'],
#  '鼻血管瘤': ['disease'],
#  '陕西东泰轻身减肥片': ['producer'],
#  '风团': ['symptom'],
#  '北京双吉红霉素眼膏': ['producer'],
#  '天津力生制药氯化钾片': ['producer'],
#  '鲁南贝特阿莫西林克拉维酸钾': ['producer'],
#  '江西捷众多潘立酮片': ['producer'],
#  '急性非化脓性一...': ['symptom'],
#  '神仙粥': ['food'],
#  '恒健制药过氧化氢溶液': ['producer'],
#  '瞬灵': ['producer'],
#  '栗子鸡翅': ['food'],
#  '江苏润邦阿奇霉素片': ['producer'],
#  '絮状沉淀试验': ['check'],
#  '七O七天然制药五子衍宗丸': ['producer'],
#  '鲁抗赛特硫酸锌片': ['producer'],
#  '肌苷口服溶液': ['drug'],
#  '西南药业复方甲苯咪唑片': ['producer'],
#  '海南三叶美好氨苄西林胶囊': ['producer'],
#  '哈森为舒硫辛酸注射液': ['producer'],
#  '闭锁肺综合征': ['disease'],
#  '包心菜猪肉粥': ['food'],
#  '人工流产': ['disease'],
#  '锦华药业土霉素片': ['producer'],
#  '溴新斯的明片': ['drug'],
#  '煎芹菜叶饼': ['food'],
#  '四川国瑞脂肪乳注射液': ['producer'],
#  '胚胎发育供血不足': ['symptom'],
#  '萌牙延迟': ['symptom'],
#  '阴道毛滴虫病': ['disease'],
#  '老年人垂体瘤': ['disease'],
#  '唐山红星哈西奈德溶液': ['producer'],
#  '可维加': ['producer'],
#  '肩关节脱位的恐惧试验': ['check'],
#  '化脓性中耳炎': ['disease'],
#  '巨人症': ['disease'],
#  '小儿爱德华兹综合征': ['disease'],
#  '大唐冠心康胶囊': ['producer'],
#  '上海上药信谊药厂盐酸普罗帕': ['producer'],
#  '白云山制药总厂丁溴东莨菪碱': ['producer'],
#  '清蒸加吉鱼': ['food'],
#  '联盛参倍固肠胶囊': ['producer'],
#  '湖南五洲通注射用盐酸丁卡因': ['producer'],
#  '前斜角肌综合征': ['disease'],
#  '苯磺酸氨氯地平片': ['drug'],
#  '小儿肥厚型心肌病': ['disease'],
#  '烟台东诚大洋消癌平片': ['producer'],
#  '镜面舌': ['symptom'],
#  '细菌学检验': ['check'],
#  '临汾宝珠维生素B1片': ['producer'],
#  '花生仁（炒）': ['food'],
#  '尼为孚': ['producer'],
#  '兴齐牛磺酸滴眼液': ['producer'],
#  '补天药业阿胶益寿口服液': ['producer'],
#  '胎儿宫内窘迫': ['disease'],
#  '蒂清': ['producer'],
#  '木耳豆腐卷': ['food'],
#  '静青吲哚美辛栓': ['producer'],
#  '喘证': ['disease'],
#  '麦考酚钠肠溶片': ['drug'],
#  '东芝堂小儿奇应丸': ['producer'],
#  '脑蛋白水解物注射液': ['drug', 'producer'],
#  '山东圣鲁环磷腺苷葡胺注射液': ['producer'],
#  '大连美罗注射用硫酸链霉素': ['producer'],
#  '头或颈部发胀及跳动感': ['symptom'],
#  '阿司匹林片': ['drug'],
#  '老年人主动脉夹层分离': ['disease'],
#  '康哲盐酸纳洛酮注射液': ['producer'],
#  '万通药业维生素E软胶囊': ['producer'],
#  '感应性妄想性障碍': ['disease'],
#  '百合雪梨莲藕汤': ['food'],
#  '唇外翻': ['symptom'],
#  '小儿贾第虫病': ['disease'],
#  '毛豆炒大芥菜': ['food'],
#  '华润紫竹醋酸可的松片': ['producer'],
#  '胰腺脓肿': ['disease'],
#  '闭眼单脚站立': ['check'],
#  '山楂桑葚子煎': ['food'],
#  '同源制药杞菊地黄口服液': ['producer'],
#  '“鸡盲”或“雀盲”': ['symptom'],
#  '天津史克莫匹罗星软膏': ['producer'],
#  '上海通用红霉素软膏': ['producer'],
#  '999茵栀黄口服液': ['producer'],
#  '三叶安比先氨苄西林胶囊': ['producer'],
#  '急性腹膜炎': ['disease'],
#  '链杆菌病': ['disease'],
#  '远程制药康尔心胶囊': ['producer'],
#  '暑瘵': ['disease'],
#  '消炎退热颗粒': ['drug'],
#  '淋巴细胞转化率': ['check'],
#  '天津金耀酒石酸美托洛尔注射': ['producer'],
#  '西安天一秦昆右旋糖酐40葡': ['producer'],
#  '鸡肝粥': ['food'],
#  '喜安林': ['producer'],
#  '沙参玉竹猪肺汤': ['food'],
#  '下半身无汗或少汗': ['symptom'],
#  '阿法根': ['producer'],
#  '脑实质的浸润': ['symptom'],
#  '供口服用': ['drug'],
#  '南京中山制药肤痒颗粒': ['producer'],
#  '法禄达': ['producer'],
#  '循环免疫复合物': ['check'],
#  '肱骨大结节骨折': ['disease'],
#  '肺力咳胶囊': ['drug'],
#  '喉症丸': ['drug'],
#  '额叶癫痫的扣带回发作': ['symptom'],
#  '河北万岁药业板蓝根颗粒': ['producer'],
#  '亨达盛康阿魏酸钠片': ['producer'],
#  '肾阴虚': ['disease'],
#  '反应迟钝': ['symptom'],
#  '孟鲁司特钠咀嚼片': ['drug'],
#  '食管贲门粘膜撕裂综合征': ['disease'],
#  '木耳烧黄花鱼': ['food'],
#  '白带pH值': ['check'],
#  '小儿糖尿病': ['disease'],
#  '肌性肌无力': ['symptom'],
#  '五景马来酸噻吗洛尔滴眼液': ['producer'],
#  '增抗宁片': ['drug'],
#  '睾丸发育不全': ['symptom'],
#  '太湖银鱼': ['food'],
#  '南国药业阿托品异丙嗪注射液': ['producer'],
#  '固肾安胎丸': ['drug'],
#  '盘龙云海排毒养颜片': ['producer'],
#  '直立性尿蛋白': ['symptom'],
#  '菊花豆腐': ['food'],
#  '金银蛋炒白菜': ['food'],
#  '同联复方甲苯咪唑片': ['producer'],
#  '手指尖痛或触痛': ['symptom'],
#  '呼吸功能衰竭': ['symptom'],
#  '广西灵峰小儿喜食片': ['producer'],
#  '痉挛性便秘': ['symptom'],
#  '伤科接骨片': ['drug'],
#  '埃莱尔-当洛综合征': ['disease'],
#  '匹多莫德胶囊': ['drug'],
#  '骨刺片': ['drug'],
#  '诺金四君子颗粒': ['producer'],
#  '急性腮腺炎性睾丸炎': ['disease'],
#  '太平洋药业氯化钠注射液': ['producer'],
#  '卓－艾氏综合征': ['disease'],
#  '手指扭伤': ['symptom'],
#  '唇厚舌大': ['symptom'],
#  'ORIONCORPORAT': ['producer'],
#  '注射用绒促性素': ['drug'],
#  '游离三碘甲状腺原氨酸指数': ['check'],
#  '赛诺菲巴斯德人用狂犬病纯化': ['producer'],
#  '出血性脑卒中': ['disease'],
#  '气管间隙形成肿块': ['symptom'],
#  '诚信制药盐酸妥洛特罗片': ['producer'],
#  '血清纤维结合蛋白': ['check'],
#  '血管伤': ['symptom'],
#  '肢体疼痛': ['symptom'],
#  '闫未娟': ['symptom'],
#  '天力泰药业复方万年青胶囊': ['producer'],
#  '清汤鲈鱼羹': ['food'],
#  '卵巢增大': ['symptom'],
#  '继发性骨髓纤维化': ['disease'],
#  '吉林济邦麝香接骨胶囊': ['producer'],
#  '华润赛科肌醇烟酸酯片': ['producer'],
#  '竹笋炒牛肉': ['food'],
#  '母鸡汤': ['food'],
#  '工业中毒所致的精神障碍': ['disease'],
#  '乳结泰胶囊': ['drug'],
#  '羊油': ['food'],
#  '健朗星': ['producer'],
#  '北京同仁堂芎菊上清丸': ['producer'],
#  '蚕豆鲫鱼粥': ['food'],
#  '江西鸿烁制药琥乙红霉素片': ['producer'],
#  '苏州中化聚卡波非钙片': ['producer'],
#  '仙琚制药克霉唑阴道片': ['producer'],
#  '兰州大得利注射用抑肽酶': ['producer'],
#  '扬子江药业黄芪精': ['producer'],
#  '广东逢春橘红丸': ['producer'],
#  '广东华润顺峰注射用盐酸罗哌': ['producer'],
#  '神志恍惚': ['symptom'],
#  '九惠制药复方丹参片': ['producer'],
#  '吉林集安益盛呋塞米注射液': ['producer'],
#  '指甲上起小细粒': ['symptom'],
#  '同仁堂理气化瘀口服液': ['producer'],
#  '纤溶酶原': ['check'],
#  '奶黄包': ['food'],
#  '精神过敏': ['symptom'],
#  '北杏炖雪梨': ['food'],
#  '鸭肉杂烩粥': ['food'],
#  '人参炖乌鸡': ['food'],
#  '抗表皮基底膜抗体': ['check'],
#  '山茱萸肉粥': ['food'],
#  '长春迪瑞猴头菌片': ['producer'],
#  '孕早期腹痛': ['symptom'],
#  '四肢不用': ['disease'],
#  '非凹陷黏液水肿': ['symptom'],
#  '盐酸克林霉素棕榈酸酯干混悬剂': ['drug'],
#  '颌下腺肿大': ['symptom'],
#  '莱姆病性巩膜炎': ['disease'],
#  '断毛癖': ['symptom'],
#  '长春银诺克尿塞通片': ['producer'],
#  '强迫性障碍': ['disease'],
#  '寰枢椎旋转脱位固定': ['disease'],
#  '海王碘酸钾片': ['producer'],
#  '丹东医创药业枸橼酸喷托维林': ['producer'],
#  '盐酸丁咯地尔注射液': ['drug'],
#  '颅痛宁颗粒': ['drug'],
#  '振东开元血尿胶囊': ['producer'],
#  '主动脉钙化': ['symptom'],
#  '武汉生物冻干人用狂犬病疫苗': ['producer'],
#  '其他类精神活性物质依赖': ['disease'],
#  '广东逢春制药安胎丸': ['producer'],
#  '颅内转移瘤': ['disease'],
#  '小儿清解颗粒': ['drug'],
#  '初生婴儿即出现...': ['symptom'],
#  '酸返流试验': ['check'],
#  '持续性咳嗽': ['symptom'],
#  '老年人椎基底动脉供血不足': ['disease'],
#  '食管外压和牵拉': ['disease'],
#  '血浆凝血因子Ⅱ活性测定': ['check'],
#  '肠球菌肺炎': ['disease'],
#  '甲钴胺胶囊': ['drug'],
#  '枸杞花旗参饮': ['food'],
#  '东洋百信疤痕止痒软化乳膏': ['producer'],
#  '声带麻痹': ['symptom'],
#  '渗出性多形红斑': ['disease'],
#  '烧伤创面暗灰或...': ['symptom'],
#  '信谊天平醋酸甲萘氢醌片': ['producer'],
#  '老黄瓜瘦肉汤': ['food'],
#  '烧酿猪大肠': ['food'],
#  '小儿哮喘性肌萎缩综合征': ['disease'],
#  '游离三碘甲状腺原氨酸': ['check'],
#  '甲芪肝纤颗粒': ['drug'],
#  '浙江南洋卡托普利片': ['producer'],
#  '澳迩药业度米芬含片': ['producer'],
#  '山西华康天王补心丸': ['producer'],
#  '肝结核': ['disease'],
#  '华纳大药厂肾炎四味胶囊': ['producer'],
#  '脏腑功能失调': ['symptom'],
#  '宁波大红鹰头孢氨苄胶囊': ['producer'],
#  '先天性白细胞颗粒异常综合征': ['disease'],
#  '近视力检查法': ['check'],
#  '普利制药积雪苷片': ['producer'],
#  '地塞米松磷酸钠注射液': ['drug', 'producer'],
#  '立庆': ['producer'],
#  '特苏安': ['producer'],
#  '外阴呈幼稚型无阴毛': ['symptom'],
#  '清热散结胶囊': ['drug'],
#  '涿州东乐阿仑膦酸钠片': ['producer'],
#  '耳内发胀': ['symptom'],
#  '健民小儿止咳糖浆': ['producer'],
#  '同济堂去痛片': ['producer'],
#  '脑性瘫痪': ['disease'],
#  '龙凤宝胶囊': ['drug'],
#  '骨放线菌病': ['disease'],
#  '天津亚宝药业盐酸二甲双胍片': ['producer'],
#  '广仁药业豆腐果苷片': ['producer'],
#  '基底节出血': ['symptom'],
#  '选择性缄默症': ['symptom'],
#  '肠道蛔虫': ['disease'],
#  '冬笋鸡丝春卷': ['food'],
#  '南宁康诺大黄碳酸氢钠片': ['producer'],
#  '太极集团利胆排石片': ['producer'],
#  '先天性鼻部皮样囊肿及瘘管': ['disease'],
#  '子宫内膜息肉': ['disease'],
#  '注射用醋酸奥曲肽': ['drug'],
#  '樱桃百合': ['food'],
#  '盐酸普拉克索片': ['drug'],
#  '鲫鱼炖猪爪': ['food'],
#  '奥泰灵': ['producer'],
#  '先天性脑积水': ['disease'],
#  '上海延安药业诺氟沙星胶囊': ['producer'],
#  '导升明': ['producer'],
#  '熊去氧胆酸片': ['drug'],
#  '烧肉蛋包饭': ['food'],
#  '北京万辉双鹤盐酸黄酮哌酯片': ['producer'],
#  '脉沉缓或沉细': ['symptom'],
#  '上海中西三维溴吡斯的明片': ['producer'],
#  '康哲广明复方丹参片': ['producer'],
#  '丹东宏业制药甲硝唑芬布芬胶': ['producer'],
#  '进行性面偏侧萎缩症': ['disease'],
#  '前足挤压试验': ['check'],
#  '花椰菜虾羹': ['food'],
#  '酒石酸伐尼克兰片': ['drug'],
#  '滑蛋牛肉': ['food'],
#  '浙江圣博康双氯芬酸钠滴眼液': ['producer'],
#  '番茄羊排粥': ['food'],
#  '湖南五洲通注射用核黄素磷酸': ['producer'],
#  '散发性脑炎': ['disease'],
#  '肠道肿瘤': ['disease'],
#  '五景盐酸萘甲唑啉滴鼻液': ['producer'],
#  '鞣酸加压素注射液': ['drug'],
#  '鸡蛋面': ['food'],
#  '产科': ['department'],
#  '通尔畅荡石片': ['producer'],
#  '丹东医创药业阿司匹林片': ['producer'],
#  '亚太药业盐酸地尔硫卓片': ['producer'],
#  '油菜拌猪肝': ['food'],
#  '江西天施康中药白花蛇舌草注': ['producer'],
#  '华雨制药脑立清丸': ['producer'],
#  '天方药业盐酸胺碘酮片': ['producer'],
#  '热带型肺嗜酸性粒细胞肺炎': ['disease'],
#  '无花果': ['food'],
#  '睡眠相位后移综合症': ['disease'],
#  '木耳黄瓜': ['food'],
#  '肺灌注显像': ['check'],
#  '莼菜羹': ['food'],
#  '甘桔冰梅片': ['drug'],
#  '熊胆黄芩滴眼液': ['drug'],
#  '鑫齐药业小儿麻甘颗粒': ['producer'],
#  '美林': ['producer'],
#  '黄河药业辛伐他汀片': ['producer'],
#  '红金消结片': ['drug'],
#  '膀胱囊肿': ['disease'],
#  '实际碳酸氢盐（AB）': ['check'],
#  '上海丽珠注射用醋酸亮丙瑞林': ['producer'],
#  '中达南岳制药转移因子注射液': ['producer'],
#  '甲状腺肿瘤': ['disease'],
#  '重庆科瑞阿昔洛韦片': ['producer'],
#  '单纯红细胞再障性贫血': ['disease'],
#  '苏州爱美津酒石酸美托洛尔片': ['producer'],
#  '流行性脑脊髓膜炎免疫学试验': ['check'],
#  '杏辉天力托吡卡胺滴眼液': ['producer'],
#  '变异型预激综合征': ['disease'],
#  '国药国瑞利巴韦林分散片': ['producer'],
#  '小儿维斯科特-奥尔德里奇综合征': ['disease'],
#  '湖北襄阳隆中补中益气丸': ['producer'],
#  '咳声嘶哑': ['symptom'],
#  '生殖道分泌物培养': ['check'],
#  '嘉进药业痔疮胶囊': ['producer'],
#  '肾动态显像': ['check'],
#  '贵州百灵双羊喉痹通颗粒': ['producer'],
#  '武汉长联来福胰岛素注射液': ['producer'],
#  '三峰热型': ['symptom'],
#  '万顺堂复方聚维酮碘搽剂': ['producer'],
#  '海南博大琥乙红霉素片': ['producer'],
#  '哈尔滨儿童制药银贝止咳颗粒': ['producer'],
#  '偏头痛': ['disease', 'symptom'],
#  '桂林南药盐酸左旋咪唑片': ['producer'],
#  '眼部毛细血管瘤': ['disease'],
#  '厄贝沙坦片': ['drug'],
#  '下呼吸道感染': ['disease'],
#  '济民可信山禾托吡卡胺滴眼液': ['producer'],
#  '产科检查': ['check'],
#  '瑞康尼莫地平片': ['producer'],
#  '成功药业复方莪术油栓': ['producer'],
#  '绝经后子宫内膜增厚': ['symptom'],
#  '百利药业利巴韦林颗粒': ['producer'],
#  '乳晕发黑': ['symptom'],
#  '老年性哮喘': ['disease'],
#  '南国药业盐酸吗啉胍片': ['producer'],
#  '中泰药业羚羊感冒片': ['producer'],
#  '胆维丁乳': ['drug'],
#  '芜湖康奇呋塞米注射液': ['producer'],
#  '白云山天心地塞米松磷酸钠注': ['producer'],
#  '运佳黄浦水杨酸软膏': ['producer'],
#  '红细胞二磷酸甘油转移酶': ['check'],
#  '乳酸性酸中毒': ['disease'],
#  '盆腔窃血试验': ['check'],
#  '慢性盆腔炎': ['disease'],
#  '九洋药业卡马西平胶囊': ['producer'],
#  '胫前和足部坚硬...': ['symptom'],
#  '鲜笋平鱼片': ['food'],
#  '颈部囊状淋巴管瘤': ['disease'],
#  '胃康灵胶囊': ['drug'],
#  '尿沉渣': ['check'],
#  '弥漫性外耳道炎': ['disease'],
#  '声阻抗检查': ['check'],
#  'δ-胆红素': ['check'],
#  '桡骨、尺骨茎突骨折': ['disease'],
#  '肺力咳合剂': ['drug'],
#  '醉酒': ['symptom'],
#  '羊肉(瘦)': ['food'],
#  '彼迪药业胶体果胶铋胶囊': ['producer'],
#  '莫匹罗星软膏': ['drug'],
#  '石药布洛芬片': ['producer'],
#  '卵巢囊肿': ['disease', 'symptom'],
#  '六安华源甘油果糖注射液': ['producer'],
#  '中间细胞(MID)': ['check'],
#  '用药过程中出现...': ['symptom'],
#  '大连水产三维鱼肝油乳': ['producer'],
#  '咬肌肥大': ['symptom'],
#  '北京同仁堂石斛夜光丸': ['producer'],
#  '益盛药业呋塞米注射液': ['producer'],
#  '骨骼变形缩短': ['symptom'],
#  '注射用甲氨蝶呤': ['drug'],
#  '小儿神经母细胞瘤': ['disease'],
#  '头孢地尼分散片': ['drug'],
#  '雄激素依赖': ['symptom'],
#  '来福生化胰岛素注射液': ['producer'],
#  '恒久远维酶素片': ['producer'],
#  '下颌反射检查': ['check'],
#  '五景药业双氯芬酸钠滴眼液': ['producer'],
#  '右旋糖酐铁口服液': ['drug'],
#  '黄瓜拌白肉': ['food'],
#  '南国药业维生素C片': ['producer'],
#  '奇星药业清热散结片': ['producer'],
#  '血热崩漏': ['disease'],
#  '百奥药业醋酸奥曲肽注射液': ['producer'],
#  '蛛网膜增厚': ['symptom'],
#  '蛋白质-热能营养障碍': ['disease'],
#  '腺淋巴瘤': ['disease'],
#  '怡康制药克拉霉素分散片': ['producer'],
#  '四川禾邦阳光小儿感冒颗粒': ['producer'],
#  '持续性枕后位、枕横位': ['disease'],
#  '兴贝维生素AD滴剂': ['producer'],
#  'Gardner综合征': ['disease'],
#  '海南斯达注射用头孢噻肟钠': ['producer'],
#  '小儿先天性直肠肛门畸形': ['disease'],
#  '牙齿上白垩色到...': ['symptom'],
#  '沙眼衣原体抗原': ['check'],
#  '前鼻镜检查': ['check'],
#  '新生儿黄疸': ['disease'],
#  '下肢红斑结节': ['symptom'],
#  '脑脊液钙': ['check'],
#  '昆明赛诺制药宁心宝胶囊': ['producer'],
#  '炒羊肚丝': ['food'],
#  '广东华南琥乙红霉素片': ['producer'],
#  '江西天之海维生素E软胶囊': ['producer'],
#  '绿十字静注人免疫球蛋白': ['producer'],
#  '结肠腺癌': ['disease'],
#  '蚕蚀性角膜溃疡': ['disease'],
#  '盐酸硫必利氯化钠注射液': ['drug'],
#  '广西梧州三箭硫酸亚铁缓释片': ['producer'],
#  '海口奇力注射用单磷酸阿糖腺': ['producer'],
#  '烫面牛肉烧卖': ['food'],
#  '布卡综合症': ['disease'],
#  '四川千方建曲': ['producer'],
#  '疣状皮肤结核': ['disease'],
#  '痰有恶臭味': ['symptom'],
#  '仁和堂药业卡托普利片': ['producer'],
#  '继发性纤溶功能增强': ['symptom'],
#  '猪肤红枣羹': ['food'],
#  '麻疹样红斑': ['disease'],
#  '扁豆泥': ['food'],
#  '亚宝养血安神片': ['producer'],
#  '口炎清片': ['drug'],
#  '米乐松': ['producer'],
#  '福星生物复方奎宁注射液': ['producer'],
#  '信谊醋酸地塞米松片': ['producer'],
#  '北京同仁堂荷叶丸': ['producer'],
#  '糖水百合汤': ['food'],
#  '苏州壹药盐酸硫必利片': ['producer'],
#  '类癌面红': ['symptom'],
#  '脸色发黄': ['symptom'],
#  '彼迪药业奋乃静片': ['producer'],
#  '白菜藕丸汤': ['food'],
#  '着色芽生菌病和暗色丝孢霉病': ['disease'],
#  '长春豪邦苦参碱氯化钠注射液': ['producer'],
#  '君寿堂骨筋丸胶囊': ['producer'],
#  '信谊盐酸金刚烷胺片': ['producer'],
#  '小儿发育性角回综合征': ['disease'],
#  '跟腱后滑囊炎': ['disease'],
#  '背部痉挛': ['symptom'],
#  '台城制药盐酸克林霉素胶囊': ['producer'],
#  '婴幼儿化脓性淋巴结炎': ['disease'],
#  '老年静脉血栓症': ['disease'],
#  '石药欧意红霉素肠溶片': ['producer'],
#  '过敏性荨麻疹': ['disease'],
#  '北京曙光卡托普利片': ['producer'],
#  '广东华润顺峰新霉素氟轻松乳': ['producer'],
#  ...}

# %% [markdown]
# ## 构造AC自动机，加速实体提取

# %% [markdown]
# 当知识图谱规模过大时，使用AC自动机算法，从问题中提取知识图谱中的实体，而不是用原生python的字符串方法。
#
# 扩展阅读：https://zhuanlan.zhihu.com/p/158767004

# %%
'''构造AC自动机，加速过滤'''
def build_actree(wordlist):
    actree = ahocorasick.Automaton()
    for index, word in enumerate(wordlist):
        actree.add_word(word, (index, word))
    actree.make_automaton()
    return actree

# %%
# 构造AC自动机
region_tree = build_actree(list(region_words))

# %%
region_tree

# %%
'血常规' in region_tree
# Out:
# True

# %%
region_tree.get('血常规')
# Out:
# (28839, '血常规')

# %%
'学习' in region_tree
# Out:
# False

# %%
region_tree.get('学习')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7304\3245028584.py in <module>
# ----> 1 region_tree.get('学习')
#
# KeyError:

# %% [markdown]
# ## 任务一：提取问题相关实体及其类别

# %%
question = '耳鸣和百日咳要做血常规吗'

# %%
question_entity = []
for each in region_tree.iter(question):
    print(each)
    entity = each[1][1]
    question_entity.append(entity)
print(question_entity) # (5, (22519, '百日咳')) 5表示该关键词出现的end_index, 则start_index = end_index - len("百日咳")
# Out:
# (1, (38348, '耳鸣'))
# (5, (22519, '百日咳'))
# (10, (28839, '血常规'))
# ['耳鸣', '百日咳', '血常规']

# %%
# stop_wds = []
# # 排除字符串子串
# for wd1 in region_wds:
#     for wd2 in region_wds:
#         if wd1 in wd2 and wd1 != wd2:
#             stop_wds.append(wd1)
# print(stop_wds)
# final_wds = [each for each in region_wds if each not in stop_wds]
# final_wds

# %%
question_entity_dict = {each:wdtype_dict[each] for each in question_entity}

# %%
question_entity_dict
# Out:
# {'耳鸣': ['disease', 'symptom'], '百日咳': ['disease'], '血常规': ['check']}

# %%
output = {}
output['args'] = question_entity_dict

# %% [markdown]
# ## 任务一完成

# %% [markdown]
# ## 任务二：提取问题相关的待查询关系

# %% [markdown]
# ### 问题中涉及的实体类别

# %%
types = []
for each in question_entity_dict.values():
    types.extend(each)

# %%
types
# Out:
# ['disease', 'symptom', 'disease', 'check']

# %% [markdown]
# ### 不同提问意图的疑问词

# %%
symptom_qwds = ['症状', '表征', '现象', '症候', '表现']
cause_qwds = ['原因','成因', '为什么', '怎么会', '怎样才', '咋样才', '怎样会', '如何会', '为啥', '为何', '如何才会', '怎么才会', '会导致', '会造成']
acompany_qwds = ['并发症', '并发', '一起发生', '一并发生', '一起出现', '一并出现', '一同发生', '一同出现', '伴随发生', '伴随', '共现']
food_qwds = ['饮食', '饮用', '吃', '食', '伙食', '膳食', '喝', '菜' ,'忌口', '补品', '保健品', '食谱', '菜谱', '食用', '食物','补品']
drug_qwds = ['药', '药品', '用药', '胶囊', '口服液', '炎片']
prevent_qwds = ['预防', '防范', '抵制', '抵御', '防止','躲避','逃避','避开','免得','逃开','避开','避掉','躲开','躲掉','绕开',
                     '怎样才能不', '怎么才能不', '咋样才能不','咋才能不', '如何才能不',
                     '怎样才不', '怎么才不', '咋样才不','咋才不', '如何才不',
                     '怎样才可以不', '怎么才可以不', '咋样才可以不', '咋才可以不', '如何可以不',
                     '怎样才可不', '怎么才可不', '咋样才可不', '咋才可不', '如何可不']
lasttime_qwds = ['周期', '多久', '多长时间', '多少时间', '几天', '几年', '多少天', '多少小时', '几个小时', '多少年']
cureway_qwds = ['怎么治疗', '如何医治', '怎么医治', '怎么治', '怎么医', '如何治', '医治方式', '疗法', '咋治', '怎么办', '咋办', '咋治']
cureprob_qwds = ['多大概率能治好', '多大几率能治好', '治好希望大么', '几率', '几成', '比例', '可能性', '能治', '可治', '可以治', '可以医']
easyget_qwds = ['易感人群', '容易感染', '易发人群', '什么人', '哪些人', '感染', '染上', '得上']
check_qwds = ['检查', '检查项目', '查出', '检查', '测出', '试出']
belong_qwds = ['属于什么科', '属于', '什么科', '科室']
cure_qwds = ['治疗什么', '治啥', '治疗啥', '医治啥', '治愈啥', '主治啥', '主治什么', '有什么用', '有何用', '用处', '用途', '有什么好处', '有什么益处', '有何益处', '用来', '用来做啥', '用来作甚', '需要', '要']

# %%
def check_words(words, question):
    # 疑问词是否出现在提问中
    for word in words:
        if word in question:
            # print(word + ' 出现在提问中')
            return True
    return False

# %%
# question_type = 'others'
question_types = []

# 疾病-症状
if check_words(symptom_qwds, question) and ('disease' in types):
    question_type = 'disease_symptom'
    question_types.append(question_type)
    
# 症状-疾病
if check_words(symptom_qwds, question) and ('symptom' in types):
    question_type = 'symptom_disease'
    question_types.append(question_type)
    
# 疾病-病因
if check_words(cause_qwds, question) and ('disease' in types):
    question_type = 'disease_cause'
    question_types.append(question_type)

# 疾病-并发症
if check_words(acompany_qwds, question) and ('disease' in types):
    question_type = 'disease_acompany'
    question_types.append(question_type)

# 疾病-可以吃/不可以吃
if check_words(food_qwds, question) and 'disease' in types:
    deny_status = check_words(deny_words, question)
    if deny_status:
        question_type = 'disease_not_food'
    else:
        question_type = 'disease_do_food'
    question_types.append(question_type)
    
# 可以吃/不可以吃-疾病
if check_words(food_qwds+cure_qwds, question) and 'food' in types:
    deny_status = check_words(deny_words, question)
    if deny_status:
        question_type = 'food_not_disease'
    else:
        question_type = 'food_do_disease'
    question_types.append(question_type)
    
# 疾病-药物
if check_words(drug_qwds, question) and 'disease' in types:
    question_type = 'disease_drug'
    question_types.append(question_type)
    
# 药物-疾病
if check_words(cure_qwds, question) and 'drug' in types:
    question_type = 'drug_disease'
    question_types.append(question_type)
    
# 疾病-检查
if check_words(check_qwds, question) and 'disease' in types:
    question_type = 'disease_check'
    question_types.append(question_type)
    
# 检查-疾病
if check_words(check_qwds+cure_qwds, question) and 'check' in types:
    question_type = 'check_disease'
    question_types.append(question_type)
    
#　疾病-预防措施
if check_words(prevent_qwds, question) and 'disease' in types:
    question_type = 'disease_prevent'
    question_types.append(question_type)
    
# 疾病-疗程
if check_words(lasttime_qwds, question) and 'disease' in types:
    question_type = 'disease_lasttime'
    question_types.append(question_type)

# 疾病-疗法
if check_words(cureway_qwds, question) and 'disease' in types:
    question_type = 'disease_cureway'
    question_types.append(question_type)

# 疾病-治愈率
if check_words(cureprob_qwds, question) and 'disease' in types:
    question_type = 'disease_cureprob'
    question_types.append(question_type)

# 疾病-易感人群
if check_words(easyget_qwds, question) and 'disease' in types :
    question_type = 'disease_easyget'
    question_types.append(question_type)

# %%
question_types
# Out:
# ['check_disease']

# %%
# 若没有查到相关的外部查询信息，那么则将该疾病的描述信息返回
if question_types == [] and 'disease' in types:
    question_types = ['disease_desc']

# 若没有查到相关的外部查询信息，那么则将该疾病的描述信息返回
if question_types == [] and 'symptom' in types:
    question_types = ['symptom_disease']

# 将多个分类结果进行合并处理，组装成一个字典
output['question_types'] = question_types

# %%
output
# Out:
# {'args': {'耳鸣': ['disease', 'symptom'], '百日咳': ['disease'], '血常规': ['check']},
#  'question_types': ['check_disease']}
